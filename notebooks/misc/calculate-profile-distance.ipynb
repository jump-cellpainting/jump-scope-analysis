# %%
# %load_ext autoreload
# %autoreload 2
import numpy as np
import scipy.spatial
import pandas as pd
from sklearn.preprocessing import LabelEncoder
import matplotlib.pyplot as plt
import seaborn as sns
import sys
sys.path.append("../../../") # Where to find utilssphering
import utilssphering
# sns.set(rc={'axes.facecolor':'white', 'figure.facecolor':'white'})

# %%
match_rep_df = pd.read_csv("/Users/ctromans/image-analysis/jump_scope/jump-scope-analysis/checkpoints/match_rep_df.csv")

# %%
# Convert string settings to numerical

def get_similar_rows(df, row_index, threshold):
    """
    For a given profile, find the most similar other rows based 
    on Euclidean distance. Rows above the threshold will be discarded

    DataFrame strings will be converted to numerical 

    ignore_cols will not be used for calculating distance, but will be returned in the final
    output 
    """
    data = df.copy()
    numerical_df = pd.DataFrame()

    comparison_cols = [
        "aperture",
        "Magnification",
        "Modality",
        "Binning",
        "Number_of_channels",
        "z_plane",
        "spinning-disc",
        "dry-immersion",
        "vs-brightfield",
        "simultaneous-excitation",
        "sites",
    ]

    drop_cols = [i for i in df.columns if i not in comparison_cols]

    display_cols = ["Vendor", "Assay_Plate_Barcode", "Batch"] + comparison_cols + ["Percent_Replicating", "Percent_Matching", "cell_count", "euclidean_distance"]

    data_dropped = data.drop(drop_cols, axis=1)

    lab = LabelEncoder()
    # Convert settings to be compared to categorical values
    for col in data_dropped.columns:
        lab.fit(data_dropped[col])
        numerical_df[col] = lab.transform(data_dropped[col])

    distances = scipy.spatial.distance.cdist(numerical_df, numerical_df, metric='euclidean')

    row = np.where(distances[row_index] > threshold, distances[row_index], 0)

    # Find indices of rows that have a distance below the threshold
    ind = np.argwhere(row==0).reshape(-1)

    # Get the relative distances for output
    comparison_distances = distances[row_index][ind]

    # Subset the data to have rows that are below the distance threshold
    data = data.iloc[ind,:]

    data["euclidean_distance"] = comparison_distances

    data = data.sort_values(by=["euclidean_distance"])

    return data[display_cols]

df = match_rep_df[
    (~match_rep_df["Batch"].str.contains("siteSub")) &
    (match_rep_df["sphering"] == True)
].reset_index()


get_ind = df.index[df["Assay_Plate_Barcode"].str.contains("20201021T092317")][0]
# get_ind = df.index[df["sites"].astype('str').str.contains("9")][11]
# get_ind = df.index[df["z_plane"].astype('str').str.contains("12")][5]

get_similar_rows(df, get_ind, 4)
# get_similar_rows(df, 25, 5, str_convert, drop_cols)[display_cols]
# Out:
#             Vendor                Assay_Plate_Barcode  \
# 45  Yokogawa_Japan                    20201021T092317
# 3           MolDev  Plate3_PCO_6ch_4site_20XPA_Crestz
# 2           MolDev  Plate3_PCO_6ch_4site_10XPA_Crestz
# 5           MolDev   Plate3_PCO_6ch_9site_20XPA_Crest
# 10           Nikon                        BR00117061a
# 11           Nikon                        BR00117062a
# 12           Nikon                        BR00117063b
# 1           MolDev   Plate3_PCO_6ch_4site_10XPA_Crest
# 4           MolDev         Plate2_PCO_6ch_9site_20XPA
# 51     Yokogawa_US                     BRO0117059_20X
# 52     Yokogawa_US                    BRO01177034_20x
# 20              PE          CP_Broad_Phenix_C_BIN1_P4
# 19              PE          CP_Broad_Phenix_C_BIN1_P3
# 18              PE          CP_Broad_Phenix_C_BIN1_P2
# 53     Yokogawa_US                     BRO0117059_40x
# 17              PE          CP_Broad_Phenix_C_BIN1_P1
# 35              PE                   CPBroadPhenixCP3
# 36              PE                   CPBroadPhenixCP4
# 34              PE                   CPBroadPhenixCP2
# 33              PE                   CPBroadPhenixCP1
# 28              PE         CP_Broad_Phenix_NC_BIN1_P4
# 26              PE         CP_Broad_Phenix_NC_BIN1_P2
# 27              PE         CP_Broad_Phenix_NC_BIN1_P3
# 25              PE         CP_Broad_Phenix_NC_BIN1_P1
# 0           MolDev         Plate2_PCO_6ch_4site_10XPA
# 44              PE                  CPBroadPhenixNCP4
# 43              PE                  CPBroadPhenixNCP3
# 42              PE                  CPBroadPhenixNCP2
# 41              PE                  CPBroadPhenixNCP1
# 13              PE   CP_Broad_Phenix_C_BIN1_1Plane_P1
# 47     Yokogawa_US                     BRO0117014_10x
# 14              PE   CP_Broad_Phenix_C_BIN1_1Plane_P2
# 16              PE   CP_Broad_Phenix_C_BIN1_1Plane_P4
# 15              PE   CP_Broad_Phenix_C_BIN1_1Plane_P3
# 50     Yokogawa_US                    BRO0117056_20xb
# 24              PE  CP_Broad_Phenix_NC_BIN1_1Plane_P4
# 21              PE  CP_Broad_Phenix_NC_BIN1_1Plane_P1
# 22              PE  CP_Broad_Phenix_NC_BIN1_1Plane_P2
# 32              PE             CPBroadPhenixC1PlaneP4
# 31              PE             CPBroadPhenixC1PlaneP3
# 30              PE             CPBroadPhenixC1PlaneP2
# 29              PE             CPBroadPhenixC1PlaneP1
# 23              PE  CP_Broad_Phenix_NC_BIN1_1Plane_P3
# 40              PE            CPBroadPhenixNC1PlaneP4
# 37              PE            CPBroadPhenixNC1PlaneP1
# 38              PE            CPBroadPhenixNC1PlaneP2
# 39              PE            CPBroadPhenixNC1PlaneP3
# 46  Yokogawa_Japan                    20201020T134356
#
#                                      Batch  aperture  Magnification  \
# 45               Scope1_Yokogawa_Japan_20X      0.75             20
# 3                  Scope1_MolDev_20X_4site      0.75             20
# 2                 Scope1_MolDev_10X_4siteZ      0.45             10
# 5                  Scope1_MolDev_20X_9site      0.75             20
# 10                        Scope1_Nikon_20X      0.75             20
# 11                        Scope1_Nikon_20X      0.75             20
# 12                        Scope1_Nikon_20X      0.75             20
# 1                        Scope1_MolDev_10X      0.45             10
# 4                  Scope1_MolDev_20X_9site      0.75             20
# 51   Scope1_Yokogawa_US_20X_6Ch_BRO0117059      1.00             20
# 52  Scope1_Yokogawa_US_20X_6Ch_BRO01177034      1.00             20
# 20          Scope1_PE_Bin1_Confocal_3Plane      1.00             20
# 19          Scope1_PE_Bin1_Confocal_3Plane      1.00             20
# 18          Scope1_PE_Bin1_Confocal_3Plane      1.00             20
# 53       Scope1_Yokogawa_US_40X_BRO0117059      1.00             40
# 17          Scope1_PE_Bin1_Confocal_3Plane      1.00             20
# 35          Scope1_PE_Bin2_Confocal_3Plane      1.00             20
# 36          Scope1_PE_Bin2_Confocal_3Plane      1.00             20
# 34          Scope1_PE_Bin2_Confocal_3Plane      1.00             20
# 33          Scope1_PE_Bin2_Confocal_3Plane      1.00             20
# 28         Scope1_PE_Bin1_Widefield_3Plane      1.00             20
# 26         Scope1_PE_Bin1_Widefield_3Plane      1.00             20
# 27         Scope1_PE_Bin1_Widefield_3Plane      1.00             20
# 25         Scope1_PE_Bin1_Widefield_3Plane      1.00             20
# 0                        Scope1_MolDev_10X      0.45             10
# 44         Scope1_PE_Bin2_Widefield_3Plane      1.00             20
# 43         Scope1_PE_Bin2_Widefield_3Plane      1.00             20
# 42         Scope1_PE_Bin2_Widefield_3Plane      1.00             20
# 41         Scope1_PE_Bin2_Widefield_3Plane      1.00             20
# 13          Scope1_PE_Bin1_Confocal_1Plane      1.00             20
# 47                  Scope1_Yokogawa_US_10X      0.40             10
# 14          Scope1_PE_Bin1_Confocal_1Plane      1.00             20
# 16          Scope1_PE_Bin1_Confocal_1Plane      1.00             20
# 15          Scope1_PE_Bin1_Confocal_1Plane      1.00             20
# 50          Scope1_Yokogawa_US_20X_5Ch_12Z      1.00             20
# 24         Scope1_PE_Bin1_Widefield_1Plane      1.00             20
# 21         Scope1_PE_Bin1_Widefield_1Plane      1.00             20
# 22         Scope1_PE_Bin1_Widefield_1Plane      1.00             20
# 32          Scope1_PE_Bin2_Confocal_1Plane      1.00             20
# 31          Scope1_PE_Bin2_Confocal_1Plane      1.00             20
# 30          Scope1_PE_Bin2_Confocal_1Plane      1.00             20
# 29          Scope1_PE_Bin2_Confocal_1Plane      1.00             20
# 23         Scope1_PE_Bin1_Widefield_1Plane      1.00             20
# 40         Scope1_PE_Bin2_Widefield_1Plane      1.00             20
# 37         Scope1_PE_Bin2_Widefield_1Plane      1.00             20
# 38         Scope1_PE_Bin2_Widefield_1Plane      1.00             20
# 39         Scope1_PE_Bin2_Widefield_1Plane      1.00             20
# 46               Scope1_Yokogawa_Japan_40X      0.95             40
#
#      Modality  Binning  Number_of_channels  z_plane spinning-disc  \
# 45   Confocal        1                   5       10           NaN
# 3    Confocal        1                   6        3           yes
# 2    Confocal        1                   6        3           yes
# 5    Confocal        1                   6        1           yes
# 10  Widefield        1                   4        1           NaN
# 11  Widefield        1                   4        1           NaN
# 12  Widefield        1                   4        1           NaN
# 1    Confocal        1                   6        1           yes
# 4    Confocal        1                   6        1            no
# 51   Confocal        1                   6       12           NaN
# 52   Confocal        1                   6       12           NaN
# 20   Confocal        1                   5        3           NaN
# 19   Confocal        1                   5        3           NaN
# 18   Confocal        1                   5        3           NaN
# 53   Confocal        1                   6       12           NaN
# 17   Confocal        1                   5        3           NaN
# 35   Confocal        2                   5        3           NaN
# 36   Confocal        2                   5        3           NaN
# 34   Confocal        2                   5        3           NaN
# 33   Confocal        2                   5        3           NaN
# 28  Widefield        1                   5        3           NaN
# 26  Widefield        1                   5        3           NaN
# 27  Widefield        1                   5        3           NaN
# 25  Widefield        1                   5        3           NaN
# 0    Confocal        1                   6        1            no
# 44  Widefield        2                   5        3           NaN
# 43  Widefield        2                   5        3           NaN
# 42  Widefield        2                   5        3           NaN
# 41  Widefield        2                   5        3           NaN
# 13   Confocal        1                   5        1           NaN
# 47   Confocal        1                   6       12           NaN
# 14   Confocal        1                   5        1           NaN
# 16   Confocal        1                   5        1           NaN
# 15   Confocal        1                   5        1           NaN
# 50   Confocal        1                   5       12           NaN
# 24  Widefield        1                   5        1           NaN
# 21  Widefield        1                   5        1           NaN
# 22  Widefield        1                   5        1           NaN
# 32   Confocal        2                   5        1           NaN
# 31   Confocal        2                   5        1           NaN
# 30   Confocal        2                   5        1           NaN
# 29   Confocal        2                   5        1           NaN
# 23  Widefield        1                   5        1           NaN
# 40  Widefield        2                   5        1           NaN
# 37  Widefield        2                   5        1           NaN
# 38  Widefield        2                   5        1           NaN
# 39  Widefield        2                   5        1           NaN
# 46   Confocal        1                   5       12           NaN
#
#    dry-immersion vs-brightfield  simultaneous-excitation  sites  \
# 45           dry            NaN                      NaN      9
# 3            dry            NaN                      NaN      4
# 2            dry            NaN                      NaN      4
# 5            dry            NaN                      NaN      9
# 10           dry            NaN                      NaN      9
# 11           dry            NaN                      NaN      9
# 12           dry            NaN                      NaN      9
# 1            dry            NaN                      NaN      4
# 4            dry            NaN                      NaN      9
# 51         water            yes                      4.0      9
# 52         water            yes                      4.0      9
# 20         water            NaN                      NaN      3
# 19         water            NaN                      NaN      3
# 18         water            NaN                      NaN      3
# 53         water            yes                      4.0      9
# 17         water            NaN                      NaN      3
# 35         water            NaN                      NaN      3
# 36         water            NaN                      NaN      3
# 34         water            NaN                      NaN      3
# 33         water            NaN                      NaN      3
# 28         water            NaN                      NaN      3
# 26         water            NaN                      NaN      3
# 27         water            NaN                      NaN      3
# 25         water            NaN                      NaN      3
# 0            dry            NaN                      NaN      4
# 44         water            NaN                      NaN      3
# 43         water            NaN                      NaN      3
# 42         water            NaN                      NaN      3
# 41         water            NaN                      NaN      3
# 13         water            NaN                      NaN      3
# 47           dry            yes                      2.0      4
# 14         water            NaN                      NaN      3
# 16         water            NaN                      NaN      3
# 15         water            NaN                      NaN      3
# 50         water             no                      2.0      9
# 24         water            NaN                      NaN      3
# 21         water            NaN                      NaN      3
# 22         water            NaN                      NaN      3
# 32         water            NaN                      NaN      3
# 31         water            NaN                      NaN      3
# 30         water            NaN                      NaN      3
# 29         water            NaN                      NaN      3
# 23         water            NaN                      NaN      3
# 40         water            NaN                      NaN      3
# 37         water            NaN                      NaN      3
# 38         water            NaN                      NaN      3
# 39         water            NaN                      NaN      3
# 46           dry             no                      NaN      2
#
#     Percent_Replicating  Percent_Matching  cell_count  euclidean_distance
# 45            64.444444         23.255814     1250600            0.000000
# 3             57.777778         18.604651      527841            2.000000
# 2             66.666667         23.255814     2381443            2.449490
# 5             58.888889         20.930233     1253387            2.449490
# 10            65.555556         23.255814     2330204            2.449490
# 11            55.555556         18.604651     2301607            2.449490
# 12            51.111111         18.604651     2274867            2.449490
# 1             62.222222         18.604651     2413350            3.000000
# 4             67.777778         23.255814     1101611            3.000000
# 51            61.111111         23.255814     1136319            3.000000
# 52            58.888889         18.604651     1045379            3.000000
# 20            57.777778         23.255814      416634            3.162278
# 19            57.777778         18.604651      370393            3.162278
# 18            57.777778         23.255814      368742            3.162278
# 53            54.444444         18.604651      279900            3.162278
# 17            58.888889         20.930233      359818            3.162278
# 35            64.444444         20.930233      355968            3.316625
# 36            60.000000         20.930233      358126            3.316625
# 34            58.888889         23.255814      355677            3.316625
# 33            58.888889         16.279070      347894            3.316625
# 28            57.777778         20.930233      403624            3.316625
# 26            57.777778         23.255814      360334            3.316625
# 27            61.111111         20.930233      361578            3.316625
# 25            58.888889         18.604651      351966            3.316625
# 0             60.000000         23.255814     2014937            3.464102
# 44            55.555556         23.255814      389393            3.464102
# 43            62.222222         20.930233      350650            3.464102
# 42            58.888889         20.930233      349751            3.464102
# 41            58.888889         20.930233      343328            3.464102
# 13            61.111111         16.279070      359491            3.605551
# 47            56.666667         23.255814     2047342            3.605551
# 14            56.666667         23.255814      368727            3.605551
# 16            57.777778         20.930233      416408            3.605551
# 15            53.333333         23.255814      369895            3.605551
# 50            66.666667         23.255814     1193638            3.741657
# 24            60.000000         25.581395      408123            3.741657
# 21            58.888889         20.930233      354572            3.741657
# 22            57.777778         25.581395      362772            3.741657
# 32            55.555556         23.255814      400114            3.741657
# 31            60.000000         23.255814      358346            3.741657
# 30            60.000000         23.255814      355872            3.741657
# 29            58.888889         23.255814      347861            3.741657
# 23            58.888889         18.604651      364413            3.741657
# 40            56.666667         25.581395      392415            3.872983
# 37            56.666667         18.604651      344830            3.872983
# 38            60.000000         25.581395      351711            3.872983
# 39            58.888889         20.930233      353232            3.872983
# 46            48.888889         18.604651       59164            4.000000

# %%
setting_df = df[comparison_cols]

numerical_df = to_numerical(setting_df, str_convert)

comparison = scipy.spatial.distance.cdist(numerical_df, numerical_df)

fig, ax = plt.subplots(figsize=(10,10))  
sns.heatmap(comparison, ax=ax)
# Out:
# <AxesSubplot:>

# %%
subset_df = match_rep_df[
    ~match_rep_df["Batch"].str.contains("siteSub") &
    match_rep_df["sphering"] == True].reset_index()

comparison_cols = [
    "aperture",
    "Magnification",
    "Modality",
    "Binning",
    "Number_of_channels",
    "z_plane",
    "spinning-disc",
    "dry-immersion",
    "vs-brightfield",
    "simultaneous-excitation",
    "sites",
]

display_cols = ["Vendor", "Assay_Plate_Barcode", "Batch"] + comparison_cols + ["Percent_Replicating", "euclidean_distance"]

df_list = list()
for barcode, batch in zip(subset_df["Assay_Plate_Barcode"], subset_df["Batch"]):
    get_ind = subset_df.index[subset_df["Assay_Plate_Barcode"].str.contains(barcode) &
                                subset_df["Batch"].str.contains(batch)][0]
    df_list.append(get_similar_rows(subset_df, get_ind, 2, drop_cols)[display_cols])

# %% [markdown]
# # Find intra and inter vendor comparisons based on euclidean distance
#
# - Inter
#   - Find within vendors the lowest euclidean distances
#     - How to drop DF that just show row rearrangements with the same distance?

# %%
for i in df_list:
    # print(i)
    i.reset_index(inplace=True, drop=True)

# %%
pd.concat(df_list).to_csv("euclidean_comparisons.csv")

# %% [markdown]
# # Other figures that are more isolated
# ## Plates to compare:
# - Plate3_PCO_6ch_4site_20XPA_Crestz
# - Plate3_PCO_6ch_9site_20XPA_Crest
# - CP_Broad_Phenix_C_BIN1_1Plane_P4
#   - Accuracy between 4 replicates
#     - Demonstrate robustness of assay within one system
# - BR00117063b
#   - Another example of the above
# - BRO01177034_20x or BRO0117059_20X vs BRO0117059_40x
#   - 20x vs 40x at 4x simultaneous excitation
# - BRO0117056_20x vs BRO0117033_20xb
#   - Yokogawa intra vendor replication. These plate settings are identical
# - BRO0117056_20xb
#   - Compare one of the above with this plate. 1 z-plane vs 12. All other settings the same.
# - BRO0117056_20xb vs BRO01177034_20x or BRO0117059_20X
#   - 4x excitation vs 2x

# %%
# %load_ext autoreload
# %autoreload 2
import utilssphering

# Define DF without batch and with sphering
df = match_rep_df[
    (~match_rep_df["Batch"].str.contains("siteSub")) &
    (match_rep_df["sphering"] == True)
].reset_index()

# Get plate index
get_ind = df.index[df["Assay_Plate_Barcode"].str.contains("Plate3_PCO_6ch_4site_20XPA_Crestz")][0]
# get_ind = df.index[df["sites"].astype('str').str.contains("9")][11]
# get_ind = df.index[df["z_plane"].astype('str').str.contains("12")][5]

df_subset = get_similar_rows(df, get_ind, 2)[:2]

fig, ax = plt.subplots(figsize=(5,5))

utilssphering.group_plot(
    df=df_subset,
    x="Percent_Matching", 
    y="Percent_Replicating",
    group=["Assay_Plate_Barcode"],
    fig=fig,
    ax_=ax,
    legend=True,
    legend_location="lower right",
    infer_custom_legend=True,
    x_lim=[16,26],
    y_lim=[38,70],
    plot_title=f"""
{df_subset["Vendor"].unique()}
{[i for i in df_subset["Assay_Plate_Barcode"]]}
""",
    xlabel="Percent Matching",
    ylabel="Percent Replicating"
)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# {'aperture': 0.45, 'Magnification': 10.0}
# {'aperture': 0.75, 'Magnification': 20.0}

# %%
# Define DF without batch and with sphering
df = match_rep_df[
    (~match_rep_df["Batch"].str.contains("siteSub")) &
    (match_rep_df["sphering"] == True)
].reset_index()

# Get plate index
get_ind = df.index[df["Assay_Plate_Barcode"].str.contains("CP_Broad_Phenix_C_BIN1_1Plane_P4")][0]
# get_ind = df.index[df["sites"].astype('str').str.contains("9")][11]
# get_ind = df.index[df["z_plane"].astype('str').str.contains("12")][5]

df_subset = get_similar_rows(df, get_ind, 2)[:4]

fig, ax = plt.subplots(figsize=(7.5,7.5))

nl = '\n'

utilssphering.group_plot(
    df=df_subset,
    x="Percent_Matching", 
    y="Percent_Replicating",
    group=["Assay_Plate_Barcode"],
    fig=fig,
    ax_=ax,
    legend=True,
    legend_location="lower right",
    # infer_custom_legend=True,
    x_lim=[16,26],
    y_lim=[38,70],
    plot_title=f"""
    Comparing replicate PE plates:
{nl.join([i for i in df_subset["Assay_Plate_Barcode"]])}
euclidean_distance = 0
""",
    xlabel="Percent Matching",
    ylabel="Percent Replicating"
)

# %%
# Define DF without batch and with sphering
df = match_rep_df[
    (~match_rep_df["Batch"].str.contains("siteSub")) &
    (match_rep_df["sphering"] == True)
].reset_index()

# Get plate index
get_ind = df.index[df["Assay_Plate_Barcode"].str.contains("BR00117063b")][0]
# get_ind = df.index[df["sites"].astype('str').str.contains("9")][11]
# get_ind = df.index[df["z_plane"].astype('str').str.contains("12")][5]

df_subset = get_similar_rows(df, get_ind, 2)[:6]

fig, ax = plt.subplots(figsize=(7.5,7.5))

nl = '\n'

utilssphering.group_plot(
    df=df_subset,
    x="Percent_Matching", 
    y="Percent_Replicating",
    group=["Assay_Plate_Barcode"],
    fig=fig,
    ax_=ax,
    legend=True,
    legend_location="lower right",
    # infer_custom_legend=True,
    x_lim=[16,26],
    y_lim=[38,70],
    plot_title=f"""
    Comparing replicate Nikon plates:
{nl.join([i for i in df_subset["Assay_Plate_Barcode"]])}
euclidean_distance = 0
""",
    xlabel="Percent Matching",
    ylabel="Percent Replicating"
)

# %%
# Define DF without batch and with sphering
df = match_rep_df[
    (~match_rep_df["Batch"].str.contains("siteSub")) &
    (match_rep_df["sphering"] == True)
].reset_index()

# Get plate index
get_ind = df.index[df["Assay_Plate_Barcode"].str.contains("BRO01177034_20x")][0]
# get_ind = df.index[df["sites"].astype('str').str.contains("9")][11]
# get_ind = df.index[df["z_plane"].astype('str').str.contains("12")][5]

df_subset = get_similar_rows(df, get_ind, 2).iloc[[0, 2]]

fig, ax = plt.subplots(figsize=(5,5))

utilssphering.group_plot(
    df=df_subset,
    x="Percent_Matching", 
    y="Percent_Replicating",
    group=["Assay_Plate_Barcode"],
    fig=fig,
    ax_=ax,
    legend=True,
    legend_location="lower right",
    infer_custom_legend=True,
    x_lim=[16,26],
    y_lim=[38,70],
    plot_title=f"""
{df_subset["Vendor"].unique()}
{[i for i in df_subset["Assay_Plate_Barcode"]]}
""",
    xlabel="Percent Matching",
    ylabel="Percent Replicating"
)

# %%
# Define DF without batch and with sphering
df = match_rep_df[
    (~match_rep_df["Batch"].str.contains("siteSub")) &
    (match_rep_df["sphering"] == True)
].reset_index()

# Get plate index
get_ind = df.index[df["Assay_Plate_Barcode"].str.contains("BRO01177034_20x")][0]
# get_ind = df.index[df["sites"].astype('str').str.contains("9")][11]
# get_ind = df.index[df["z_plane"].astype('str').str.contains("12")][5]

df_subset = get_similar_rows(df, get_ind, 2).iloc[[0, 2]]

fig, ax = plt.subplots(figsize=(5,5))

utilssphering.group_plot(
    df=df_subset,
    x="Percent_Matching", 
    y="Percent_Replicating",
    group=["Assay_Plate_Barcode"],
    fig=fig,
    ax_=ax,
    legend=True,
    legend_location="lower right",
    infer_custom_legend=True,
    x_lim=[16,26],
    y_lim=[38,70],
    plot_title=f"""
{df_subset["Vendor"].unique()}
{[i for i in df_subset["Assay_Plate_Barcode"]]}
""",
    xlabel="Percent Matching",
    ylabel="Percent Replicating"
)

# %%
# Define DF without batch and with sphering
df = match_rep_df[
    (~match_rep_df["Batch"].str.contains("siteSub")) &
    (match_rep_df["sphering"] == True)
].reset_index()

# Get plate index
get_ind = df.index[df["Assay_Plate_Barcode"].str.contains("BRO0117056_20x")][0]
# get_ind = df.index[df["sites"].astype('str').str.contains("9")][11]
# get_ind = df.index[df["z_plane"].astype('str').str.contains("12")][5]

df_subset = get_similar_rows(df, get_ind, 2)
df_subset

fig, ax = plt.subplots(figsize=(5,5))

utilssphering.group_plot(
    df=df_subset,
    x="Percent_Matching", 
    y="Percent_Replicating",
    group=["Assay_Plate_Barcode"],
    fig=fig,
    ax_=ax,
    legend=True,
    legend_location="lower right",
    # infer_custom_legend=True,
    x_lim=[16,26],
    y_lim=[38,70],
    plot_title=f"""
    Comparing replicate Yokogawa_US plates:
{[i for i in df_subset["Assay_Plate_Barcode"]]}
""",
    xlabel="Percent Matching",
    ylabel="Percent Replicating"
)

# %%
# Define DF without batch and with sphering
df = match_rep_df[
    (~match_rep_df["Batch"].str.contains("siteSub")) &
    (match_rep_df["sphering"] == True)
].reset_index()

# Get plate index
get_ind = df.index[df["Assay_Plate_Barcode"].str.contains("BRO0117056_20xb")][0]
# get_ind = df.index[df["sites"].astype('str').str.contains("9")][11]
# get_ind = df.index[df["z_plane"].astype('str').str.contains("12")][5]

df_subset = get_similar_rows(df, get_ind, 4).iloc[[0, 4]]
df_subset

fig, ax = plt.subplots(figsize=(5,5))

utilssphering.group_plot(
    df=df_subset,
    x="Percent_Matching", 
    y="Percent_Replicating",
    group=["Assay_Plate_Barcode"],
    fig=fig,
    ax_=ax,
    legend=True,
    legend_location="lower right",
    infer_custom_legend=True,
    x_lim=[16,26],
    y_lim=[38,70],
    plot_title=f"""
{df_subset["Vendor"].unique()}
{[i for i in df_subset["Assay_Plate_Barcode"]]}
""",
    xlabel="Percent Matching",
    ylabel="Percent Replicating"
)

# %%
get_similar_rows(df, get_ind, 4)
# Out:
#             Vendor        Assay_Plate_Barcode  \
# 50     Yokogawa_US            BRO0117056_20xb
# 51     Yokogawa_US             BRO0117059_20X
# 52     Yokogawa_US            BRO01177034_20x
# 53     Yokogawa_US             BRO0117059_40x
# 48     Yokogawa_US            BRO0117033_20xb
# 49     Yokogawa_US             BRO0117056_20x
# 45  Yokogawa_Japan            20201021T092317
# 17              PE  CP_Broad_Phenix_C_BIN1_P1
# 18              PE  CP_Broad_Phenix_C_BIN1_P2
# 19              PE  CP_Broad_Phenix_C_BIN1_P3
# 20              PE  CP_Broad_Phenix_C_BIN1_P4
# 46  Yokogawa_Japan            20201020T134356
#
#                                      Batch  aperture  Magnification  Modality  \
# 50          Scope1_Yokogawa_US_20X_5Ch_12Z      1.00             20  Confocal
# 51   Scope1_Yokogawa_US_20X_6Ch_BRO0117059      1.00             20  Confocal
# 52  Scope1_Yokogawa_US_20X_6Ch_BRO01177034      1.00             20  Confocal
# 53       Scope1_Yokogawa_US_40X_BRO0117059      1.00             40  Confocal
# 48              Scope1_Yokogawa_US_20X_5Ch      1.00             20  Confocal
# 49              Scope1_Yokogawa_US_20X_5Ch      1.00             20  Confocal
# 45               Scope1_Yokogawa_Japan_20X      0.75             20  Confocal
# 17          Scope1_PE_Bin1_Confocal_3Plane      1.00             20  Confocal
# 18          Scope1_PE_Bin1_Confocal_3Plane      1.00             20  Confocal
# 19          Scope1_PE_Bin1_Confocal_3Plane      1.00             20  Confocal
# 20          Scope1_PE_Bin1_Confocal_3Plane      1.00             20  Confocal
# 46               Scope1_Yokogawa_Japan_40X      0.95             40  Confocal
#
#     Binning  Number_of_channels  z_plane spinning-disc dry-immersion  \
# 50        1                   5       12           NaN         water
# 51        1                   6       12           NaN         water
# 52        1                   6       12           NaN         water
# 53        1                   6       12           NaN         water
# 48        1                   5        1           NaN         water
# 49        1                   5        1           NaN         water
# 45        1                   5       10           NaN           dry
# 17        1                   5        3           NaN         water
# 18        1                   5        3           NaN         water
# 19        1                   5        3           NaN         water
# 20        1                   5        3           NaN         water
# 46        1                   5       12           NaN           dry
#
#    vs-brightfield  simultaneous-excitation  sites  Percent_Replicating  \
# 50             no                      2.0      9            66.666667
# 51            yes                      4.0      9            61.111111
# 52            yes                      4.0      9            58.888889
# 53            yes                      4.0      9            54.444444
# 48             no                      2.0      9            61.111111
# 49             no                      2.0      9            58.888889
# 45            NaN                      NaN      9            64.444444
# 17            NaN                      NaN      3            58.888889
# 18            NaN                      NaN      3            57.777778
# 19            NaN                      NaN      3            57.777778
# 20            NaN                      NaN      3            57.777778
# 46             no                      NaN      2            48.888889
#
#     Percent_Matching  cell_count  euclidean_distance
# 50         23.255814     1193638            0.000000
# 51         23.255814     1136319            1.732051
# 52         18.604651     1045379            1.732051
# 53         18.604651      279900            2.000000
# 48         18.604651     1096617            3.000000
# 49         25.581395     1191329            3.000000
# 45         23.255814     1250600            3.741657
# 17         20.930233      359818            4.000000
# 18         23.255814      368742            4.000000
# 19         18.604651      370393            4.000000
# 20         23.255814      416634            4.000000
# 46         18.604651       59164            4.000000

# %%
# Define DF without batch and with sphering
df = match_rep_df[
    (~match_rep_df["Batch"].str.contains("siteSub")) &
    (match_rep_df["sphering"] == True)
].reset_index()

# Get plate index
get_ind = df.index[df["Assay_Plate_Barcode"].str.contains("BRO01177034_20x")][0]
# get_ind = df.index[~df["simultaneous-excitation"].isnull()][1]
# get_ind = df.index[df["sites"].astype('str').str.contains("9")][11]
# get_ind = df.index[df["z_plane"].astype('str').str.contains("12")][5]

df_subset = get_similar_rows(df, get_ind, 4).iloc[[0, 3]]
df_subset

fig, ax = plt.subplots(figsize=(7.5,5))

utilssphering.group_plot(
    df=df_subset,
    x="Percent_Matching", 
    y="Percent_Replicating",
    group=["Assay_Plate_Barcode"],
    fig=fig,
    ax_=ax,
    legend=True,
    legend_location="lower right",
    infer_custom_legend=True,
    x_lim=[16,26],
    y_lim=[38,70],
    plot_title=f"""
Comparing Yokogawa_US similar plates (12 z-planes)
{[i for i in df_subset["Assay_Plate_Barcode"]]}
euclidean_distance 1.732051
""",
    xlabel="Percent Matching",
    ylabel="Percent Replicating"
)

# %% [markdown]
# # All 4x simultaneous excitation profiles have 12z planes

# %%
# Define DF without batch and with sphering
df = match_rep_df[
    (~match_rep_df["Batch"].str.contains("siteSub")) &
    (match_rep_df["sphering"] == True)
].reset_index()

# Get plate index
get_ind = df.index[df["Assay_Plate_Barcode"].str.contains("BRO0117014_10x")][0]
# get_ind = df.index[~df["simultaneous-excitation"].isnull()][1]
# get_ind = df.index[df["sites"].astype('str').str.contains("9")][11]
# get_ind = df.index[df["z_plane"].astype('str').str.contains("12")][5]

df_subset = get_similar_rows(df, get_ind, 10).iloc[[0, 6]]
df_subset

fig, ax = plt.subplots(figsize=(7.5,5))

utilssphering.group_plot(
    df=df_subset,
    x="Percent_Matching", 
    y="Percent_Replicating",
    group=["Assay_Plate_Barcode"],
    fig=fig,
    ax_=ax,
    legend=True,
    legend_location="lower right",
    infer_custom_legend=True,
    x_lim=[16,26],
    y_lim=[38,70],
    plot_title=f"""
Comparing Yokogawa_US that have 12 z-planes 
{[i for i in df_subset["Assay_Plate_Barcode"]]}
euclidean_distance 4.472136
""",
    xlabel="Percent Matching",
    ylabel="Percent Replicating"
)

# %%
# The euclidean distance between 2x and 4x simultaneous excitation is low
get_ind = df.index[~df["simultaneous-excitation"].isnull()][1]

# df_subset = get_similar_rows(df, get_ind, 10).iloc[[0, -5]]
df_subset = get_similar_rows(df, get_ind, 10)
df_subset
# Out:
#             Vendor                Assay_Plate_Barcode  \
# 49     Yokogawa_US                     BRO0117056_20x
# 48     Yokogawa_US                    BRO0117033_20xb
# 50     Yokogawa_US                    BRO0117056_20xb
# 14              PE   CP_Broad_Phenix_C_BIN1_1Plane_P2
# 51     Yokogawa_US                     BRO0117059_20X
# 15              PE   CP_Broad_Phenix_C_BIN1_1Plane_P3
# 52     Yokogawa_US                    BRO01177034_20x
# 16              PE   CP_Broad_Phenix_C_BIN1_1Plane_P4
# 13              PE   CP_Broad_Phenix_C_BIN1_1Plane_P1
# 19              PE          CP_Broad_Phenix_C_BIN1_P3
# 20              PE          CP_Broad_Phenix_C_BIN1_P4
# 24              PE  CP_Broad_Phenix_NC_BIN1_1Plane_P4
# 22              PE  CP_Broad_Phenix_NC_BIN1_1Plane_P2
# 23              PE  CP_Broad_Phenix_NC_BIN1_1Plane_P3
# 32              PE             CPBroadPhenixC1PlaneP4
# 31              PE             CPBroadPhenixC1PlaneP3
# 21              PE  CP_Broad_Phenix_NC_BIN1_1Plane_P1
# 18              PE          CP_Broad_Phenix_C_BIN1_P2
# 53     Yokogawa_US                     BRO0117059_40x
# 30              PE             CPBroadPhenixC1PlaneP2
# 17              PE          CP_Broad_Phenix_C_BIN1_P1
# 29              PE             CPBroadPhenixC1PlaneP1
# 33              PE                   CPBroadPhenixCP1
# 34              PE                   CPBroadPhenixCP2
# 35              PE                   CPBroadPhenixCP3
# 36              PE                   CPBroadPhenixCP4
# 37              PE            CPBroadPhenixNC1PlaneP1
# 38              PE            CPBroadPhenixNC1PlaneP2
# 39              PE            CPBroadPhenixNC1PlaneP3
# 40              PE            CPBroadPhenixNC1PlaneP4
# 26              PE         CP_Broad_Phenix_NC_BIN1_P2
# 27              PE         CP_Broad_Phenix_NC_BIN1_P3
# 25              PE         CP_Broad_Phenix_NC_BIN1_P1
# 28              PE         CP_Broad_Phenix_NC_BIN1_P4
# 44              PE                  CPBroadPhenixNCP4
# 43              PE                  CPBroadPhenixNCP3
# 41              PE                  CPBroadPhenixNCP1
# 5           MolDev   Plate3_PCO_6ch_9site_20XPA_Crest
# 42              PE                  CPBroadPhenixNCP2
# 10           Nikon                        BR00117061a
# 11           Nikon                        BR00117062a
# 12           Nikon                        BR00117063b
# 45  Yokogawa_Japan                    20201021T092317
# 3           MolDev  Plate3_PCO_6ch_4site_20XPA_Crestz
# 4           MolDev         Plate2_PCO_6ch_9site_20XPA
# 1           MolDev   Plate3_PCO_6ch_4site_10XPA_Crest
# 2           MolDev  Plate3_PCO_6ch_4site_10XPA_Crestz
# 46  Yokogawa_Japan                    20201020T134356
# 0           MolDev         Plate2_PCO_6ch_4site_10XPA
# 47     Yokogawa_US                     BRO0117014_10x
# 6            Nikon                     BR00117060a10x
# 8            Nikon                     BR00117062a10x
# 9            Nikon                     BR00117063b10x
# 7            Nikon                     BR00117061a10x
#
#                                      Batch  aperture  Magnification  \
# 49              Scope1_Yokogawa_US_20X_5Ch      1.00             20
# 48              Scope1_Yokogawa_US_20X_5Ch      1.00             20
# 50          Scope1_Yokogawa_US_20X_5Ch_12Z      1.00             20
# 14          Scope1_PE_Bin1_Confocal_1Plane      1.00             20
# 51   Scope1_Yokogawa_US_20X_6Ch_BRO0117059      1.00             20
# 15          Scope1_PE_Bin1_Confocal_1Plane      1.00             20
# 52  Scope1_Yokogawa_US_20X_6Ch_BRO01177034      1.00             20
# 16          Scope1_PE_Bin1_Confocal_1Plane      1.00             20
# 13          Scope1_PE_Bin1_Confocal_1Plane      1.00             20
# 19          Scope1_PE_Bin1_Confocal_3Plane      1.00             20
# 20          Scope1_PE_Bin1_Confocal_3Plane      1.00             20
# 24         Scope1_PE_Bin1_Widefield_1Plane      1.00             20
# 22         Scope1_PE_Bin1_Widefield_1Plane      1.00             20
# 23         Scope1_PE_Bin1_Widefield_1Plane      1.00             20
# 32          Scope1_PE_Bin2_Confocal_1Plane      1.00             20
# 31          Scope1_PE_Bin2_Confocal_1Plane      1.00             20
# 21         Scope1_PE_Bin1_Widefield_1Plane      1.00             20
# 18          Scope1_PE_Bin1_Confocal_3Plane      1.00             20
# 53       Scope1_Yokogawa_US_40X_BRO0117059      1.00             40
# 30          Scope1_PE_Bin2_Confocal_1Plane      1.00             20
# 17          Scope1_PE_Bin1_Confocal_3Plane      1.00             20
# 29          Scope1_PE_Bin2_Confocal_1Plane      1.00             20
# 33          Scope1_PE_Bin2_Confocal_3Plane      1.00             20
# 34          Scope1_PE_Bin2_Confocal_3Plane      1.00             20
# 35          Scope1_PE_Bin2_Confocal_3Plane      1.00             20
# 36          Scope1_PE_Bin2_Confocal_3Plane      1.00             20
# 37         Scope1_PE_Bin2_Widefield_1Plane      1.00             20
# 38         Scope1_PE_Bin2_Widefield_1Plane      1.00             20
# 39         Scope1_PE_Bin2_Widefield_1Plane      1.00             20
# 40         Scope1_PE_Bin2_Widefield_1Plane      1.00             20
# 26         Scope1_PE_Bin1_Widefield_3Plane      1.00             20
# 27         Scope1_PE_Bin1_Widefield_3Plane      1.00             20
# 25         Scope1_PE_Bin1_Widefield_3Plane      1.00             20
# 28         Scope1_PE_Bin1_Widefield_3Plane      1.00             20
# 44         Scope1_PE_Bin2_Widefield_3Plane      1.00             20
# 43         Scope1_PE_Bin2_Widefield_3Plane      1.00             20
# 41         Scope1_PE_Bin2_Widefield_3Plane      1.00             20
# 5                  Scope1_MolDev_20X_9site      0.75             20
# 42         Scope1_PE_Bin2_Widefield_3Plane      1.00             20
# 10                        Scope1_Nikon_20X      0.75             20
# 11                        Scope1_Nikon_20X      0.75             20
# 12                        Scope1_Nikon_20X      0.75             20
# 45               Scope1_Yokogawa_Japan_20X      0.75             20
# 3                  Scope1_MolDev_20X_4site      0.75             20
# 4                  Scope1_MolDev_20X_9site      0.75             20
# 1                        Scope1_MolDev_10X      0.45             10
# 2                 Scope1_MolDev_10X_4siteZ      0.45             10
# 46               Scope1_Yokogawa_Japan_40X      0.95             40
# 0                        Scope1_MolDev_10X      0.45             10
# 47                  Scope1_Yokogawa_US_10X      0.40             10
# 6                         Scope1_Nikon_10X      0.45             10
# 8                         Scope1_Nikon_10X      0.45             10
# 9                         Scope1_Nikon_10X      0.45             10
# 7                         Scope1_Nikon_10X      0.45             10
#
#      Modality  Binning  Number_of_channels  z_plane spinning-disc  \
# 49   Confocal        1                   5        1           NaN
# 48   Confocal        1                   5        1           NaN
# 50   Confocal        1                   5       12           NaN
# 14   Confocal        1                   5        1           NaN
# 51   Confocal        1                   6       12           NaN
# 15   Confocal        1                   5        1           NaN
# 52   Confocal        1                   6       12           NaN
# 16   Confocal        1                   5        1           NaN
# 13   Confocal        1                   5        1           NaN
# 19   Confocal        1                   5        3           NaN
# 20   Confocal        1                   5        3           NaN
# 24  Widefield        1                   5        1           NaN
# 22  Widefield        1                   5        1           NaN
# 23  Widefield        1                   5        1           NaN
# 32   Confocal        2                   5        1           NaN
# 31   Confocal        2                   5        1           NaN
# 21  Widefield        1                   5        1           NaN
# 18   Confocal        1                   5        3           NaN
# 53   Confocal        1                   6       12           NaN
# 30   Confocal        2                   5        1           NaN
# 17   Confocal        1                   5        3           NaN
# 29   Confocal        2                   5        1           NaN
# 33   Confocal        2                   5        3           NaN
# 34   Confocal        2                   5        3           NaN
# 35   Confocal        2                   5        3           NaN
# 36   Confocal        2                   5        3           NaN
# 37  Widefield        2                   5        1           NaN
# 38  Widefield        2                   5        1           NaN
# 39  Widefield        2                   5        1           NaN
# 40  Widefield        2                   5        1           NaN
# 26  Widefield        1                   5        3           NaN
# 27  Widefield        1                   5        3           NaN
# 25  Widefield        1                   5        3           NaN
# 28  Widefield        1                   5        3           NaN
# 44  Widefield        2                   5        3           NaN
# 43  Widefield        2                   5        3           NaN
# 41  Widefield        2                   5        3           NaN
# 5    Confocal        1                   6        1           yes
# 42  Widefield        2                   5        3           NaN
# 10  Widefield        1                   4        1           NaN
# 11  Widefield        1                   4        1           NaN
# 12  Widefield        1                   4        1           NaN
# 45   Confocal        1                   5       10           NaN
# 3    Confocal        1                   6        3           yes
# 4    Confocal        1                   6        1            no
# 1    Confocal        1                   6        1           yes
# 2    Confocal        1                   6        3           yes
# 46   Confocal        1                   5       12           NaN
# 0    Confocal        1                   6        1            no
# 47   Confocal        1                   6       12           NaN
# 6   Widefield        1                   4        1           NaN
# 8   Widefield        1                   4        1           NaN
# 9   Widefield        1                   4        1           NaN
# 7   Widefield        1                   4        1           NaN
#
#    dry-immersion vs-brightfield  simultaneous-excitation  sites  \
# 49         water             no                      2.0      9
# 48         water             no                      2.0      9
# 50         water             no                      2.0      9
# 14         water            NaN                      NaN      3
# 51         water            yes                      4.0      9
# 15         water            NaN                      NaN      3
# 52         water            yes                      4.0      9
# 16         water            NaN                      NaN      3
# 13         water            NaN                      NaN      3
# 19         water            NaN                      NaN      3
# 20         water            NaN                      NaN      3
# 24         water            NaN                      NaN      3
# 22         water            NaN                      NaN      3
# 23         water            NaN                      NaN      3
# 32         water            NaN                      NaN      3
# 31         water            NaN                      NaN      3
# 21         water            NaN                      NaN      3
# 18         water            NaN                      NaN      3
# 53         water            yes                      4.0      9
# 30         water            NaN                      NaN      3
# 17         water            NaN                      NaN      3
# 29         water            NaN                      NaN      3
# 33         water            NaN                      NaN      3
# 34         water            NaN                      NaN      3
# 35         water            NaN                      NaN      3
# 36         water            NaN                      NaN      3
# 37         water            NaN                      NaN      3
# 38         water            NaN                      NaN      3
# 39         water            NaN                      NaN      3
# 40         water            NaN                      NaN      3
# 26         water            NaN                      NaN      3
# 27         water            NaN                      NaN      3
# 25         water            NaN                      NaN      3
# 28         water            NaN                      NaN      3
# 44         water            NaN                      NaN      3
# 43         water            NaN                      NaN      3
# 41         water            NaN                      NaN      3
# 5            dry            NaN                      NaN      9
# 42         water            NaN                      NaN      3
# 10           dry            NaN                      NaN      9
# 11           dry            NaN                      NaN      9
# 12           dry            NaN                      NaN      9
# 45           dry            NaN                      NaN      9
# 3            dry            NaN                      NaN      4
# 4            dry            NaN                      NaN      9
# 1            dry            NaN                      NaN      4
# 2            dry            NaN                      NaN      4
# 46           dry             no                      NaN      2
# 0            dry            NaN                      NaN      4
# 47           dry            yes                      2.0      4
# 6            dry            NaN                      NaN      1
# 8            dry            NaN                      NaN      1
# 9            dry            NaN                      NaN      1
# 7            dry            NaN                      NaN      1
#
#     Percent_Replicating  Percent_Matching  cell_count  euclidean_distance
# 49            58.888889         25.581395     1191329            0.000000
# 48            61.111111         18.604651     1096617            0.000000
# 50            66.666667         23.255814     1193638            3.000000
# 14            56.666667         23.255814      368727            3.464102
# 51            61.111111         23.255814     1136319            3.464102
# 15            53.333333         23.255814      369895            3.464102
# 52            58.888889         18.604651     1045379            3.464102
# 16            57.777778         20.930233      416408            3.464102
# 13            61.111111         16.279070      359491            3.464102
# 19            57.777778         18.604651      370393            3.605551
# 20            57.777778         23.255814      416634            3.605551
# 24            60.000000         25.581395      408123            3.605551
# 22            57.777778         25.581395      362772            3.605551
# 23            58.888889         18.604651      364413            3.605551
# 32            55.555556         23.255814      400114            3.605551
# 31            60.000000         23.255814      358346            3.605551
# 21            58.888889         20.930233      354572            3.605551
# 18            57.777778         23.255814      368742            3.605551
# 53            54.444444         18.604651      279900            3.605551
# 30            60.000000         23.255814      355872            3.605551
# 17            58.888889         20.930233      359818            3.605551
# 29            58.888889         23.255814      347861            3.605551
# 33            58.888889         16.279070      347894            3.741657
# 34            58.888889         23.255814      355677            3.741657
# 35            64.444444         20.930233      355968            3.741657
# 36            60.000000         20.930233      358126            3.741657
# 37            56.666667         18.604651      344830            3.741657
# 38            60.000000         25.581395      351711            3.741657
# 39            58.888889         20.930233      353232            3.741657
# 40            56.666667         25.581395      392415            3.741657
# 26            57.777778         23.255814      360334            3.741657
# 27            61.111111         20.930233      361578            3.741657
# 25            58.888889         18.604651      351966            3.741657
# 28            57.777778         20.930233      403624            3.741657
# 44            55.555556         23.255814      389393            3.872983
# 43            62.222222         20.930233      350650            3.872983
# 41            58.888889         20.930233      343328            3.872983
# 5             58.888889         20.930233     1253387            3.872983
# 42            58.888889         20.930233      349751            3.872983
# 10            65.555556         23.255814     2330204            3.872983
# 11            55.555556         18.604651     2301607            3.872983
# 12            51.111111         18.604651     2274867            3.872983
# 45            64.444444         23.255814     1250600            4.123106
# 3             57.777778         18.604651      527841            4.123106
# 4             67.777778         23.255814     1101611            4.242641
# 1             62.222222         18.604651     2413350            4.690416
# 2             66.666667         23.255814     2381443            4.795832
# 46            48.888889         18.604651       59164            5.000000
# 0             60.000000         23.255814     2014937            5.000000
# 47            56.666667         23.255814     2047342            5.477226
# 6             42.222222         16.279070      929255            6.082763
# 8             40.000000         16.279070      925656            6.082763
# 9             44.943820         16.666667      910533            6.082763
# 7             54.545455         19.512195      938495            6.082763

# %%
get_ind = df.index[df["Assay_Plate_Barcode"].str.contains("20201020T134356")][0]
df_subset = get_similar_rows(df, get_ind, 10)
df_subset
# Out:
#             Vendor                Assay_Plate_Barcode  \
# 46  Yokogawa_Japan                    20201020T134356
# 17              PE          CP_Broad_Phenix_C_BIN1_P1
# 19              PE          CP_Broad_Phenix_C_BIN1_P3
# 20              PE          CP_Broad_Phenix_C_BIN1_P4
# 18              PE          CP_Broad_Phenix_C_BIN1_P2
# 25              PE         CP_Broad_Phenix_NC_BIN1_P1
# 27              PE         CP_Broad_Phenix_NC_BIN1_P3
# 28              PE         CP_Broad_Phenix_NC_BIN1_P4
# 33              PE                   CPBroadPhenixCP1
# 26              PE         CP_Broad_Phenix_NC_BIN1_P2
# 36              PE                   CPBroadPhenixCP4
# 35              PE                   CPBroadPhenixCP3
# 34              PE                   CPBroadPhenixCP2
# 41              PE                  CPBroadPhenixNCP1
# 42              PE                  CPBroadPhenixNCP2
# 43              PE                  CPBroadPhenixNCP3
# 44              PE                  CPBroadPhenixNCP4
# 53     Yokogawa_US                     BRO0117059_40x
# 51     Yokogawa_US                     BRO0117059_20X
# 52     Yokogawa_US                    BRO01177034_20x
# 3           MolDev  Plate3_PCO_6ch_4site_20XPA_Crestz
# 45  Yokogawa_Japan                    20201021T092317
# 50     Yokogawa_US                    BRO0117056_20xb
# 15              PE   CP_Broad_Phenix_C_BIN1_1Plane_P3
# 14              PE   CP_Broad_Phenix_C_BIN1_1Plane_P2
# 13              PE   CP_Broad_Phenix_C_BIN1_1Plane_P1
# 16              PE   CP_Broad_Phenix_C_BIN1_1Plane_P4
# 32              PE             CPBroadPhenixC1PlaneP4
# 31              PE             CPBroadPhenixC1PlaneP3
# 30              PE             CPBroadPhenixC1PlaneP2
# 29              PE             CPBroadPhenixC1PlaneP1
# 24              PE  CP_Broad_Phenix_NC_BIN1_1Plane_P4
# 23              PE  CP_Broad_Phenix_NC_BIN1_1Plane_P3
# 22              PE  CP_Broad_Phenix_NC_BIN1_1Plane_P2
# 21              PE  CP_Broad_Phenix_NC_BIN1_1Plane_P1
# 37              PE            CPBroadPhenixNC1PlaneP1
# 38              PE            CPBroadPhenixNC1PlaneP2
# 39              PE            CPBroadPhenixNC1PlaneP3
# 40              PE            CPBroadPhenixNC1PlaneP4
# 2           MolDev  Plate3_PCO_6ch_4site_10XPA_Crestz
# 47     Yokogawa_US                     BRO0117014_10x
# 7            Nikon                     BR00117061a10x
# 6            Nikon                     BR00117060a10x
# 8            Nikon                     BR00117062a10x
# 9            Nikon                     BR00117063b10x
# 48     Yokogawa_US                    BRO0117033_20xb
# 49     Yokogawa_US                     BRO0117056_20x
# 10           Nikon                        BR00117061a
# 11           Nikon                        BR00117062a
# 12           Nikon                        BR00117063b
# 5           MolDev   Plate3_PCO_6ch_9site_20XPA_Crest
# 1           MolDev   Plate3_PCO_6ch_4site_10XPA_Crest
# 4           MolDev         Plate2_PCO_6ch_9site_20XPA
# 0           MolDev         Plate2_PCO_6ch_4site_10XPA
#
#                                      Batch  aperture  Magnification  \
# 46               Scope1_Yokogawa_Japan_40X      0.95             40
# 17          Scope1_PE_Bin1_Confocal_3Plane      1.00             20
# 19          Scope1_PE_Bin1_Confocal_3Plane      1.00             20
# 20          Scope1_PE_Bin1_Confocal_3Plane      1.00             20
# 18          Scope1_PE_Bin1_Confocal_3Plane      1.00             20
# 25         Scope1_PE_Bin1_Widefield_3Plane      1.00             20
# 27         Scope1_PE_Bin1_Widefield_3Plane      1.00             20
# 28         Scope1_PE_Bin1_Widefield_3Plane      1.00             20
# 33          Scope1_PE_Bin2_Confocal_3Plane      1.00             20
# 26         Scope1_PE_Bin1_Widefield_3Plane      1.00             20
# 36          Scope1_PE_Bin2_Confocal_3Plane      1.00             20
# 35          Scope1_PE_Bin2_Confocal_3Plane      1.00             20
# 34          Scope1_PE_Bin2_Confocal_3Plane      1.00             20
# 41         Scope1_PE_Bin2_Widefield_3Plane      1.00             20
# 42         Scope1_PE_Bin2_Widefield_3Plane      1.00             20
# 43         Scope1_PE_Bin2_Widefield_3Plane      1.00             20
# 44         Scope1_PE_Bin2_Widefield_3Plane      1.00             20
# 53       Scope1_Yokogawa_US_40X_BRO0117059      1.00             40
# 51   Scope1_Yokogawa_US_20X_6Ch_BRO0117059      1.00             20
# 52  Scope1_Yokogawa_US_20X_6Ch_BRO01177034      1.00             20
# 3                  Scope1_MolDev_20X_4site      0.75             20
# 45               Scope1_Yokogawa_Japan_20X      0.75             20
# 50          Scope1_Yokogawa_US_20X_5Ch_12Z      1.00             20
# 15          Scope1_PE_Bin1_Confocal_1Plane      1.00             20
# 14          Scope1_PE_Bin1_Confocal_1Plane      1.00             20
# 13          Scope1_PE_Bin1_Confocal_1Plane      1.00             20
# 16          Scope1_PE_Bin1_Confocal_1Plane      1.00             20
# 32          Scope1_PE_Bin2_Confocal_1Plane      1.00             20
# 31          Scope1_PE_Bin2_Confocal_1Plane      1.00             20
# 30          Scope1_PE_Bin2_Confocal_1Plane      1.00             20
# 29          Scope1_PE_Bin2_Confocal_1Plane      1.00             20
# 24         Scope1_PE_Bin1_Widefield_1Plane      1.00             20
# 23         Scope1_PE_Bin1_Widefield_1Plane      1.00             20
# 22         Scope1_PE_Bin1_Widefield_1Plane      1.00             20
# 21         Scope1_PE_Bin1_Widefield_1Plane      1.00             20
# 37         Scope1_PE_Bin2_Widefield_1Plane      1.00             20
# 38         Scope1_PE_Bin2_Widefield_1Plane      1.00             20
# 39         Scope1_PE_Bin2_Widefield_1Plane      1.00             20
# 40         Scope1_PE_Bin2_Widefield_1Plane      1.00             20
# 2                 Scope1_MolDev_10X_4siteZ      0.45             10
# 47                  Scope1_Yokogawa_US_10X      0.40             10
# 7                         Scope1_Nikon_10X      0.45             10
# 6                         Scope1_Nikon_10X      0.45             10
# 8                         Scope1_Nikon_10X      0.45             10
# 9                         Scope1_Nikon_10X      0.45             10
# 48              Scope1_Yokogawa_US_20X_5Ch      1.00             20
# 49              Scope1_Yokogawa_US_20X_5Ch      1.00             20
# 10                        Scope1_Nikon_20X      0.75             20
# 11                        Scope1_Nikon_20X      0.75             20
# 12                        Scope1_Nikon_20X      0.75             20
# 5                  Scope1_MolDev_20X_9site      0.75             20
# 1                        Scope1_MolDev_10X      0.45             10
# 4                  Scope1_MolDev_20X_9site      0.75             20
# 0                        Scope1_MolDev_10X      0.45             10
#
#      Modality  Binning  Number_of_channels  z_plane spinning-disc  \
# 46   Confocal        1                   5       12           NaN
# 17   Confocal        1                   5        3           NaN
# 19   Confocal        1                   5        3           NaN
# 20   Confocal        1                   5        3           NaN
# 18   Confocal        1                   5        3           NaN
# 25  Widefield        1                   5        3           NaN
# 27  Widefield        1                   5        3           NaN
# 28  Widefield        1                   5        3           NaN
# 33   Confocal        2                   5        3           NaN
# 26  Widefield        1                   5        3           NaN
# 36   Confocal        2                   5        3           NaN
# 35   Confocal        2                   5        3           NaN
# 34   Confocal        2                   5        3           NaN
# 41  Widefield        2                   5        3           NaN
# 42  Widefield        2                   5        3           NaN
# 43  Widefield        2                   5        3           NaN
# 44  Widefield        2                   5        3           NaN
# 53   Confocal        1                   6       12           NaN
# 51   Confocal        1                   6       12           NaN
# 52   Confocal        1                   6       12           NaN
# 3    Confocal        1                   6        3           yes
# 45   Confocal        1                   5       10           NaN
# 50   Confocal        1                   5       12           NaN
# 15   Confocal        1                   5        1           NaN
# 14   Confocal        1                   5        1           NaN
# 13   Confocal        1                   5        1           NaN
# 16   Confocal        1                   5        1           NaN
# 32   Confocal        2                   5        1           NaN
# 31   Confocal        2                   5        1           NaN
# 30   Confocal        2                   5        1           NaN
# 29   Confocal        2                   5        1           NaN
# 24  Widefield        1                   5        1           NaN
# 23  Widefield        1                   5        1           NaN
# 22  Widefield        1                   5        1           NaN
# 21  Widefield        1                   5        1           NaN
# 37  Widefield        2                   5        1           NaN
# 38  Widefield        2                   5        1           NaN
# 39  Widefield        2                   5        1           NaN
# 40  Widefield        2                   5        1           NaN
# 2    Confocal        1                   6        3           yes
# 47   Confocal        1                   6       12           NaN
# 7   Widefield        1                   4        1           NaN
# 6   Widefield        1                   4        1           NaN
# 8   Widefield        1                   4        1           NaN
# 9   Widefield        1                   4        1           NaN
# 48   Confocal        1                   5        1           NaN
# 49   Confocal        1                   5        1           NaN
# 10  Widefield        1                   4        1           NaN
# 11  Widefield        1                   4        1           NaN
# 12  Widefield        1                   4        1           NaN
# 5    Confocal        1                   6        1           yes
# 1    Confocal        1                   6        1           yes
# 4    Confocal        1                   6        1            no
# 0    Confocal        1                   6        1            no
#
#    dry-immersion vs-brightfield  simultaneous-excitation  sites  \
# 46           dry             no                      NaN      2
# 17         water            NaN                      NaN      3
# 19         water            NaN                      NaN      3
# 20         water            NaN                      NaN      3
# 18         water            NaN                      NaN      3
# 25         water            NaN                      NaN      3
# 27         water            NaN                      NaN      3
# 28         water            NaN                      NaN      3
# 33         water            NaN                      NaN      3
# 26         water            NaN                      NaN      3
# 36         water            NaN                      NaN      3
# 35         water            NaN                      NaN      3
# 34         water            NaN                      NaN      3
# 41         water            NaN                      NaN      3
# 42         water            NaN                      NaN      3
# 43         water            NaN                      NaN      3
# 44         water            NaN                      NaN      3
# 53         water            yes                      4.0      9
# 51         water            yes                      4.0      9
# 52         water            yes                      4.0      9
# 3            dry            NaN                      NaN      4
# 45           dry            NaN                      NaN      9
# 50         water             no                      2.0      9
# 15         water            NaN                      NaN      3
# 14         water            NaN                      NaN      3
# 13         water            NaN                      NaN      3
# 16         water            NaN                      NaN      3
# 32         water            NaN                      NaN      3
# 31         water            NaN                      NaN      3
# 30         water            NaN                      NaN      3
# 29         water            NaN                      NaN      3
# 24         water            NaN                      NaN      3
# 23         water            NaN                      NaN      3
# 22         water            NaN                      NaN      3
# 21         water            NaN                      NaN      3
# 37         water            NaN                      NaN      3
# 38         water            NaN                      NaN      3
# 39         water            NaN                      NaN      3
# 40         water            NaN                      NaN      3
# 2            dry            NaN                      NaN      4
# 47           dry            yes                      2.0      4
# 7            dry            NaN                      NaN      1
# 6            dry            NaN                      NaN      1
# 8            dry            NaN                      NaN      1
# 9            dry            NaN                      NaN      1
# 48         water             no                      2.0      9
# 49         water             no                      2.0      9
# 10           dry            NaN                      NaN      9
# 11           dry            NaN                      NaN      9
# 12           dry            NaN                      NaN      9
# 5            dry            NaN                      NaN      9
# 1            dry            NaN                      NaN      4
# 4            dry            NaN                      NaN      9
# 0            dry            NaN                      NaN      4
#
#     Percent_Replicating  Percent_Matching  cell_count  euclidean_distance
# 46            48.888889         18.604651       59164            0.000000
# 17            58.888889         20.930233      359818            3.464102
# 19            57.777778         18.604651      370393            3.464102
# 20            57.777778         23.255814      416634            3.464102
# 18            57.777778         23.255814      368742            3.464102
# 25            58.888889         18.604651      351966            3.605551
# 27            61.111111         20.930233      361578            3.605551
# 28            57.777778         20.930233      403624            3.605551
# 33            58.888889         16.279070      347894            3.605551
# 26            57.777778         23.255814      360334            3.605551
# 36            60.000000         20.930233      358126            3.605551
# 35            64.444444         20.930233      355968            3.605551
# 34            58.888889         23.255814      355677            3.605551
# 41            58.888889         20.930233      343328            3.741657
# 42            58.888889         20.930233      349751            3.741657
# 43            62.222222         20.930233      350650            3.741657
# 44            55.555556         23.255814      389393            3.741657
# 53            54.444444         18.604651      279900            3.741657
# 51            61.111111         23.255814     1136319            3.872983
# 52            58.888889         18.604651     1045379            3.872983
# 3             57.777778         18.604651      527841            4.000000
# 45            64.444444         23.255814     1250600            4.000000
# 50            66.666667         23.255814     1193638            4.000000
# 15            53.333333         23.255814      369895            4.123106
# 14            56.666667         23.255814      368727            4.123106
# 13            61.111111         16.279070      359491            4.123106
# 16            57.777778         20.930233      416408            4.123106
# 32            55.555556         23.255814      400114            4.242641
# 31            60.000000         23.255814      358346            4.242641
# 30            60.000000         23.255814      355872            4.242641
# 29            58.888889         23.255814      347861            4.242641
# 24            60.000000         25.581395      408123            4.242641
# 23            58.888889         18.604651      364413            4.242641
# 22            57.777778         25.581395      362772            4.242641
# 21            58.888889         20.930233      354572            4.242641
# 37            56.666667         18.604651      344830            4.358899
# 38            60.000000         25.581395      351711            4.358899
# 39            58.888889         20.930233      353232            4.358899
# 40            56.666667         25.581395      392415            4.358899
# 2             66.666667         23.255814     2381443            4.690416
# 47            56.666667         23.255814     2047342            4.795832
# 7             54.545455         19.512195      938495            4.898979
# 6             42.222222         16.279070      929255            4.898979
# 8             40.000000         16.279070      925656            4.898979
# 9             44.943820         16.666667      910533            4.898979
# 48            61.111111         18.604651     1096617            5.000000
# 49            58.888889         25.581395     1191329            5.000000
# 10            65.555556         23.255814     2330204            5.099020
# 11            55.555556         18.604651     2301607            5.099020
# 12            51.111111         18.604651     2274867            5.099020
# 5             58.888889         20.930233     1253387            5.099020
# 1             62.222222         18.604651     2413350            5.196152
# 4             67.777778         23.255814     1101611            5.385165
# 0             60.000000         23.255814     2014937            5.477226
