# %%
import sys
sys.path.append("../../../") # Where to find utilssphering
import utilssphering
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Read CSV
match_rep_df = pd.read_csv("../../../checkpoints/match_rep_df.csv")
match_rep_df
# Out:
#           Vendor                                              Batch  \
# 0         MolDev                                  Scope1_MolDev_10X
# 1         MolDev                                  Scope1_MolDev_10X
# 2         MolDev                                  Scope1_MolDev_10X
# 3         MolDev                                  Scope1_MolDev_10X
# 4         MolDev                           Scope1_MolDev_10X_4siteZ
# ..           ...                                                ...
# 357  Yokogawa_US  4siteSubSample_Scope1_Yokogawa_US_20X_6Ch_BRO0...
# 358  Yokogawa_US  4siteSubSample_Scope1_Yokogawa_US_20X_6Ch_BRO0...
# 359  Yokogawa_US  4siteSubSample_Scope1_Yokogawa_US_20X_6Ch_BRO0...
# 360  Yokogawa_US   4siteSubSample_Scope1_Yokogawa_US_40X_BRO0117059
# 361  Yokogawa_US   4siteSubSample_Scope1_Yokogawa_US_40X_BRO0117059
#
#                    Assay_Plate_Barcode  sphering  value_95_replicating  \
# 0           Plate2_PCO_6ch_4site_10XPA      True              0.200046
# 1           Plate2_PCO_6ch_4site_10XPA     False              0.420650
# 2     Plate3_PCO_6ch_4site_10XPA_Crest      True              0.268013
# 3     Plate3_PCO_6ch_4site_10XPA_Crest     False              0.338900
# 4    Plate3_PCO_6ch_4site_10XPA_Crestz      True              0.205121
# ..                                 ...       ...                   ...
# 357                     BRO0117059_20X     False              0.628379
# 358                    BRO01177034_20x      True              0.139090
# 359                    BRO01177034_20x     False              0.666818
# 360                     BRO0117059_40x      True              0.193787
# 361                     BRO0117059_40x     False              0.331777
#
#      Percent_Replicating              Plate_Map_Name  Modality  \
# 0              57.777778  JUMP-MOA_compound_platemap  Confocal
# 1              35.555556  JUMP-MOA_compound_platemap  Confocal
# 2              62.222222  JUMP-MOA_compound_platemap  Confocal
# 3              47.777778  JUMP-MOA_compound_platemap  Confocal
# 4              66.666667  JUMP-MOA_compound_platemap  Confocal
# ..                   ...                         ...       ...
# 357            20.000000  JUMP-MOA_compound_platemap  Confocal
# 358            56.666667  JUMP-MOA_compound_platemap  Confocal
# 359            21.111111  JUMP-MOA_compound_platemap  Confocal
# 360            53.333333  JUMP-MOA_compound_platemap  Confocal
# 361            36.666667  JUMP-MOA_compound_platemap  Confocal
#
#      Images_per_well  Sites-SubSampled  ...  aperture  dry-immersion  \
# 0                  4               NaN  ...      0.45            dry
# 1                  4               NaN  ...      0.45            dry
# 2                  4               NaN  ...      0.45            dry
# 3                  4               NaN  ...      0.45            dry
# 4                  4               NaN  ...      0.45            dry
# ..               ...               ...  ...       ...            ...
# 357                9               4.0  ...      1.00          water
# 358                9               4.0  ...      1.00          water
# 359                9               4.0  ...      1.00          water
# 360                9               4.0  ...      1.00          water
# 361                9               4.0  ...      1.00          water
#
#      vs-brightfield  simultaneous-excitation sites    Size_MB  Size_MB_std  \
# 0               NaN                      NaN     4  52.476334     0.000144
# 1               NaN                      NaN     4  52.476334     0.000144
# 2               NaN                      NaN     4  52.476514     0.000183
# 3               NaN                      NaN     4  52.476514     0.000183
# 4               NaN                      NaN     4  52.476631     0.000142
# ..              ...                      ...   ...        ...          ...
# 357             NaN                      NaN     4   7.954439     0.000583
# 358             NaN                      NaN     4   8.003584     0.000014
# 359             NaN                      NaN     4   8.003584     0.000014
# 360             NaN                      NaN     4   7.971628     0.080201
# 361             NaN                      NaN     4   7.971628     0.080201
#
#     Percent_Matching value_95_matching  cell_count
# 0          20.930233          0.303191     2014937
# 1          16.279070          0.307224     2014937
# 2          20.930233          0.401802     2413350
# 3          16.279070          0.411854     2413350
# 4          23.255814          0.363114     2381443
# ..               ...               ...         ...
# 357         6.976744          0.772160      489099
# 358        18.604651          0.193171      452567
# 359         9.302326          0.790813      452567
# 360        20.930233          0.234702      116595
# 361        13.953488          0.336164      116595
#
# [362 rows x 26 columns]

# %% [markdown]
# ## Alternative figure legend
#
# A - Assessment of magnification and aperture on ability to replicate profiles between wells treated with drugs with identical MoA (replicating) vs drugs with a similar MoA (matching)
# B - Examining how number of sites taken per well impacts profile strength
# C - All profiles were aggregated based on the number of sites used. Errorbar = SD
# D - For profiles with 9 images per well, data was randomly subsampled to 4, 3, 2, and 1 site(s). Errorbar = SD
# E - For the profiles examined in D, the cell count for each profile.

# %%
# A

group = ["Magnification", "aperture"]

df_subset = match_rep_df[
                        (match_rep_df["sphering"] == True) &
                        (~match_rep_df["Batch"].str.contains("siteSub"))
                        ]

group_df = utilssphering.find_group_avg_df(df_subset, group)

fig, ax = plt.subplots(figsize=(5,5))

utilssphering.group_plot(
    df=group_df,
    x="Mean_Percent_Matching", 
    y="Mean_Percent_Replicating",
    group=group,
    error_x="SD_Percent_Matching",
    error_y="SD_Percent_Replicating",
    fig=fig,
    ax_=ax
)
utilssphering.group_plot(
    df_subset, 
    "Percent_Matching", 
    "Percent_Replicating", 
    group=group, 
    fig=fig, 
    ax_=ax, 
    legend=True)

# fig.savefig("(A-ALT)-rep-vs-match-mag_aperture.png")

# %%
# B 
# Plot profile subsamples that originally had 9 images per well

group = "sites"

df_subset = match_rep_df[
                        (match_rep_df["sphering"] == True) &
                        (~match_rep_df["Batch"].str.contains("siteSub"))
                        ]

group_df = utilssphering.find_group_avg_df(df_subset, group)

fig, ax = plt.subplots(figsize=(5,5))

utilssphering.group_plot(
    df_subset, 
    "Percent_Matching", 
    "Percent_Replicating", 
    group=group, 
    fig=fig, 
    ax_=ax, 
    legend=True)

utilssphering.group_plot(
    df=group_df, 
    x="Mean_Percent_Matching", 
    y="Mean_Percent_Replicating",
    group=group,
    error_x="SD_Percent_Matching",
    error_y="SD_Percent_Replicating",
    fig=fig,
    ax_=ax
)

# %%
# C

group_columns = "sites"

df_subset = match_rep_df[
                        (~match_rep_df["Batch"].str.contains("siteSubSample")) & 
                        (match_rep_df["sphering"] == True) 
                        ]

group_df = utilssphering.find_group_avg_df(df_subset, group)

fig, ax = plt.subplots(figsize=(5,5))

utilssphering.group_plot(
    df=group_df,
    x=group, 
    y="Mean_Percent_Replicating",
    group=group,
    fig=fig,
    ax_=ax,
    legend=True
)
# Plot the errorbars
utilssphering.group_plot(
    df=group_df, 
    x=group, 
    y="Mean_Percent_Replicating",
    group=group,
    # error_x="SD_Percent_Replicating",
    error_y="SD_Percent_Replicating",
    fig=fig,
    ax_=ax
)
        
# fig.savefig("figures/mean_rep-against-sites.png")

# %%
# D
# Plot profile subsamples that originally had 9 images per well

group = "sites"

plot_plates = ["Plate2_PCO_6ch_9site_20XPA",
                "Plate3_PCO_6ch_9site_20XPA_Crest",
                "BR00117061a",
                "BR00117062a",
                "BR00117063b",
                "20201021T092317",
                "BRO0117033_20xb",
                "BRO0117056_20x",
                "BRO0117056_20xb",
                "BRO0117059_20X",
                "BRO01177034_20x",
                "BRO0117059_40x"]

df_subset = match_rep_df[
                        (match_rep_df["Assay_Plate_Barcode"].str.contains("|".join(plot_plates))) & 
                        (match_rep_df["sphering"] == True) 
                        ]

group_df = utilssphering.find_group_avg_df(df_subset, group)

fig, ax = plt.subplots(figsize=(5,5))

utilssphering.group_plot(
    df=group_df,
    x=group, 
    y="Mean_Percent_Replicating",
    group=group,
    fig=fig,
    ax_=ax,
    legend=True
)
utilssphering.group_plot(
    df=group_df, 
    x=group, 
    y="Mean_Percent_Replicating",
    group=group,
    # error_x="SD_Percent_Replicating",
    error_y="SD_Percent_Replicating",
    fig=fig,
    ax_=ax
)

# %%
# E

group = "sites"

plot_plates = ["Plate2_PCO_6ch_9site_20XPA",
                "Plate3_PCO_6ch_9site_20XPA_Crest",
                "BR00117061a",
                "BR00117062a",
                "BR00117063b",
                "20201021T092317",
                "BRO0117033_20xb",
                "BRO0117056_20x",
                "BRO0117056_20xb",
                "BRO0117059_20X",
                "BRO01177034_20x",
                "BRO0117059_40x"]

df_subset = match_rep_df[
                        (match_rep_df["Assay_Plate_Barcode"].str.contains("|".join(plot_plates))) & 
                        (match_rep_df["sphering"] == True) 
                        ]

group_df = utilssphering.find_group_avg_df(df_subset, group)

fig, ax = plt.subplots(figsize=(5,5))

utilssphering.group_plot(
    df=df_subset,
    x=group, 
    y="cell_count",
    group=group,
    fig=fig,
    ax_=ax,
    legend=True
)

fig.savefig("(D)-cell_count-vs-sites.png")
