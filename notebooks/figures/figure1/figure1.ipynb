# %%
import sys
sys.path.append("../../../") # Where to find utilssphering
import utilssphering
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Read CSV
match_rep_df = pd.read_csv("../../../checkpoints/match_rep_df.csv")
match_rep_df
# Out:
#           Vendor                                              Batch  \
# 0         MolDev                                  Scope1_MolDev_10X
# 1         MolDev                                  Scope1_MolDev_10X
# 2         MolDev                                  Scope1_MolDev_10X
# 3         MolDev                                  Scope1_MolDev_10X
# 4         MolDev                           Scope1_MolDev_10X_4siteZ
# ..           ...                                                ...
# 357  Yokogawa_US  4siteSubSample_Scope1_Yokogawa_US_20X_6Ch_BRO0...
# 358  Yokogawa_US  4siteSubSample_Scope1_Yokogawa_US_20X_6Ch_BRO0...
# 359  Yokogawa_US  4siteSubSample_Scope1_Yokogawa_US_20X_6Ch_BRO0...
# 360  Yokogawa_US   4siteSubSample_Scope1_Yokogawa_US_40X_BRO0117059
# 361  Yokogawa_US   4siteSubSample_Scope1_Yokogawa_US_40X_BRO0117059
#
#                    Assay_Plate_Barcode  sphering  value_95_replicating  \
# 0           Plate2_PCO_6ch_4site_10XPA      True              0.191908
# 1           Plate2_PCO_6ch_4site_10XPA     False              0.269727
# 2     Plate3_PCO_6ch_4site_10XPA_Crest      True              0.269617
# 3     Plate3_PCO_6ch_4site_10XPA_Crest     False              0.329074
# 4    Plate3_PCO_6ch_4site_10XPA_Crestz      True              0.205121
# ..                                 ...       ...                   ...
# 357                     BRO0117059_20X     False              0.628379
# 358                    BRO01177034_20x      True              0.139090
# 359                    BRO01177034_20x     False              0.666818
# 360                     BRO0117059_40x      True              0.193787
# 361                     BRO0117059_40x     False              0.331777
#
#      Percent_Replicating              Plate_Map_Name  Modality  \
# 0              60.000000  JUMP-MOA_compound_platemap  Confocal
# 1              53.333333  JUMP-MOA_compound_platemap  Confocal
# 2              62.222222  JUMP-MOA_compound_platemap  Confocal
# 3              45.555556  JUMP-MOA_compound_platemap  Confocal
# 4              66.666667  JUMP-MOA_compound_platemap  Confocal
# ..                   ...                         ...       ...
# 357            20.000000  JUMP-MOA_compound_platemap  Confocal
# 358            56.666667  JUMP-MOA_compound_platemap  Confocal
# 359            21.111111  JUMP-MOA_compound_platemap  Confocal
# 360            53.333333  JUMP-MOA_compound_platemap  Confocal
# 361            36.666667  JUMP-MOA_compound_platemap  Confocal
#
#      Images_per_well  Sites-SubSampled  ...  simultaneous-excitation  sites  \
# 0                  4               NaN  ...                      NaN      4
# 1                  4               NaN  ...                      NaN      4
# 2                  4               NaN  ...                      NaN      4
# 3                  4               NaN  ...                      NaN      4
# 4                  4               NaN  ...                      NaN      4
# ..               ...               ...  ...                      ...    ...
# 357                9               4.0  ...                      4.0      4
# 358                9               4.0  ...                      1.0      4
# 359                9               4.0  ...                      1.0      4
# 360                9               4.0  ...                      4.0      4
# 361                9               4.0  ...                      4.0      4
#
#        Size_MB  Size_MB_std                         channel_names  \
# 0    52.476334     0.000144      Actin, DNA, ER, Golgi, Mito, RNA
# 1    52.476334     0.000144      Actin, DNA, ER, Golgi, Mito, RNA
# 2    52.476514     0.000183      Actin, DNA, ER, Golgi, Mito, RNA
# 3    52.476514     0.000183      Actin, DNA, ER, Golgi, Mito, RNA
# 4    52.476631     0.000142      Actin, DNA, ER, Golgi, Mito, RNA
# ..         ...          ...                                   ...
# 357   7.954439     0.000583  AGP, BrightField, DNA, ER, Mito, RNA
# 358   8.003584     0.000014  AGP, BrightField, DNA, ER, Mito, RNA
# 359   8.003584     0.000014  AGP, BrightField, DNA, ER, Mito, RNA
# 360   7.971628     0.080201  AGP, BrightField, DNA, ER, Mito, RNA
# 361   7.971628     0.080201  AGP, BrightField, DNA, ER, Mito, RNA
#
#     brightfield_z_plane_used                feature_channels_found  \
# 0                        NaN      Actin, DNA, ER, Golgi, Mito, RNA
# 1                        NaN      Actin, DNA, ER, Golgi, Mito, RNA
# 2                        NaN      Actin, DNA, ER, Golgi, Mito, RNA
# 3                        NaN      Actin, DNA, ER, Golgi, Mito, RNA
# 4                        NaN      Actin, DNA, ER, Golgi, Mito, RNA
# ..                       ...                                   ...
# 357                      Z08  AGP, BrightField, DNA, ER, Mito, RNA
# 358                      Z17  AGP, BrightField, DNA, ER, Mito, RNA
# 359                      Z17  AGP, BrightField, DNA, ER, Mito, RNA
# 360                      Z08  AGP, BrightField, DNA, ER, Mito, RNA
# 361                      Z08  AGP, BrightField, DNA, ER, Mito, RNA
#
#     Percent_Matching value_95_matching  cell_count
# 0          23.255814          0.288099     2014937
# 1          18.604651          0.320855     2014937
# 2          18.604651          0.398249     2413350
# 3          18.604651          0.389170     2413350
# 4          23.255814          0.363114     2381443
# ..               ...               ...         ...
# 357         6.976744          0.772160      489099
# 358        18.604651          0.193171      452567
# 359         9.302326          0.790813      452567
# 360        20.930233          0.234702      116595
# 361        13.953488          0.336164      116595
#
# [362 rows x 29 columns]

# %%
# A

group = "Magnification"

df_subset = match_rep_df[
                        (match_rep_df["sphering"] == True) &
                        (~match_rep_df["Batch"].str.contains("siteSub")) 
                        ]

group_df = utilssphering.find_group_avg_df(df_subset, group)

fig, ax = plt.subplots(figsize=(5,5))

utilssphering.group_plot(
    df=group_df,
    x="Mean_Percent_Matching", 
    y="Mean_Percent_Replicating",
    group=group,
    error_x="SD_Percent_Matching",
    error_y="SD_Percent_Replicating",
    fig=fig,
    ax_=ax
)
utilssphering.group_plot(
    df_subset, 
    "Percent_Matching", 
    "Percent_Replicating", 
    group=group, 
    fig=fig, 
    ax_=ax, 
    legend=True,
    alpha=0.5
    )

fig.savefig("(A)-rep-vs-match-mag.png", dpi=300)

# %%
# B 

group = "sites"

df_subset = match_rep_df[
                        (match_rep_df["sphering"] == True) &
                        (~match_rep_df["Batch"].str.contains("siteSub")) 
                        ]

group_df = utilssphering.find_group_avg_df(df_subset, group)

fig, ax = plt.subplots(figsize=(5,5))

utilssphering.group_plot(
    df=group_df,
    x="Mean_Percent_Matching", 
    y="Mean_Percent_Replicating",
    group=group,
    error_x="SD_Percent_Matching",
    error_y="SD_Percent_Replicating",
    fig=fig,
    ax_=ax
)
utilssphering.group_plot(
    df_subset, 
    "Percent_Matching", 
    "Percent_Replicating", 
    group=group, 
    fig=fig, 
    ax_=ax, 
    legend=True,
    alpha=0.5
    )

fig.savefig("(B)-rep-vs-match-sites.png", dpi=300)

# %%
# C

group = "Magnification"

df_subset = match_rep_df[
    (match_rep_df["sphering"] == True)
    # & (~match_rep_df["Vendor"].str.contains("PE"))
    ]

additional_cols = {
    "col1": ["cell_count", "Mean_Cell_Count", lambda x: np.mean(x)],
    "col2": ["cell_count", "SD_Cell_Count", lambda z: float('%.3f'%np.std(z))]
}
group_df = utilssphering.find_group_avg_df(df_subset, group, add_cols=additional_cols)

fig, ax = plt.subplots(figsize=(5,5))

utilssphering.group_plot(
    df=group_df, 
    x="Mean_Cell_Count", 
    y="Mean_Percent_Replicating",
    group=group,
    error_x="SD_Cell_Count",
    error_y="SD_Percent_Replicating",
    fig=fig,
    ax_=ax
)
utilssphering.group_plot(
    df_subset, 
    "cell_count", 
    "Percent_Replicating", 
    group=group, 
    fig=fig, 
    ax_=ax, 
    legend=True)


fig.savefig("(C)-rep-vs-cell_count-mag.png", dpi=300)

# %%
# D

group = "sites"

df_subset = match_rep_df[(match_rep_df["sphering"] == True)]

additional_cols = {
    "col1": ["cell_count", "Mean_Cell_Count", lambda x: np.mean(x)],
    "col2": ["cell_count", "SD_Cell_Count", lambda z: float('%.3f'%np.std(z))]
}

fig, ax = plt.subplots(figsize=(5,5))

utilssphering.group_plot(
    df_subset, 
    "cell_count", 
    "Percent_Replicating", 
    group=group, 
    fig=fig, 
    ax_=ax, 
    legend=True)

fig.savefig("(D)-rep-vs-cell_count-sites.png", dpi=300)

# %%
# A

# group = ["Magnification", "z_plane"]
group = "Magnification"

df_subset = match_rep_df[
                        (match_rep_df["sphering"] == True) &
                        (~match_rep_df["Batch"].str.contains("siteSub")) 
                        ]

group_df = utilssphering.find_group_avg_df(df_subset, group)

fig, ax = plt.subplots(figsize=(5,5))

# utilssphering.group_plot(
#     df=group_df,
#     # x="z_plane", 
#     y="Mean_Percent_Replicating",
#     group=group,
#     # error_x="SD_Percent_Matching",
#     error_y="SD_Percent_Replicating",
#     fig=fig,
#     ax_=ax
# )
utilssphering.group_plot(
    df_subset, 
    "z_plane", 
    "Percent_Replicating", 
    group=group, 
    fig=fig, 
    ax_=ax, 
    legend=True,
    alpha=0.5
    )

# fig.savefig("(A)-rep-vs-match-mag.png", dpi=300)
