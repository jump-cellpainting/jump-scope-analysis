# %%
# %load_ext autoreload
# %autoreload 2


import sys
sys.path.append("../../../") # Where to find utilssphering
import utilssphering
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Read CSV
match_rep_df = pd.read_csv("../../../checkpoints/match_rep_df.csv")
match_rep_df
# Out:
#           Vendor                                              Batch  \
# 0         MolDev                                  Scope1_MolDev_10X
# 1         MolDev                                  Scope1_MolDev_10X
# 2         MolDev                           Scope1_MolDev_10X_4siteZ
# 3         MolDev                            Scope1_MolDev_20X_4site
# 4         MolDev                            Scope1_MolDev_20X_9site
# ..           ...                                                ...
# 177  Yokogawa_US      4siteSubSample_Scope1_Yokogawa_US_20X_5Ch_12Z
# 178  Yokogawa_US  4siteSubSample_Scope1_Yokogawa_US_20X_6Ch_BRO0...
# 179  Yokogawa_US  4siteSubSample_Scope1_Yokogawa_US_20X_6Ch_BRO0...
# 180  Yokogawa_US   4siteSubSample_Scope1_Yokogawa_US_40X_BRO0117059
# 181  Yokogawa_US   1siteSubSample_Scope1_Yokogawa_US_40X_BRO0117059
#
#                  Plate_Map_Name                Assay_Plate_Barcode   Modality  \
# 0    JUMP-MOA_compound_platemap         Plate2_PCO_6ch_4site_10XPA  Widefield
# 1    JUMP-MOA_compound_platemap   Plate3_PCO_6ch_4site_10XPA_Crest   Confocal
# 2    JUMP-MOA_compound_platemap  Plate3_PCO_6ch_4site_10XPA_Crestz   Confocal
# 3    JUMP-MOA_compound_platemap  Plate3_PCO_6ch_4site_20XPA_Crestz   Confocal
# 4    JUMP-MOA_compound_platemap         Plate2_PCO_6ch_9site_20XPA  Widefield
# ..                          ...                                ...        ...
# 177  JUMP-MOA_compound_platemap                    BRO0117056_20xb   Confocal
# 178  JUMP-MOA_compound_platemap                     BRO0117059_20X   Confocal
# 179  JUMP-MOA_compound_platemap                    BRO01177034_20x   Confocal
# 180  JUMP-MOA_compound_platemap                     BRO0117059_40x   Confocal
# 181  JUMP-MOA_compound_platemap                     BRO0117059_40x   Confocal
#
#      Images_per_well  Sites-SubSampled  Binning  Magnification  \
# 0                  4               NaN        1             10
# 1                  4               NaN        1             10
# 2                  4               NaN        1             10
# 3                  4               NaN        1             20
# 4                  9               NaN        1             20
# ..               ...               ...      ...            ...
# 177                9               4.0        1             20
# 178                9               4.0        1             20
# 179                9               4.0        1             20
# 180                9               4.0        1             40
# 181                9               2.0        1             40
#
#      Number_of_channels  ...  Size_MB_std sphering  value_95_replicating  \
# 0                     6  ...     0.000144     True              0.191908
# 1                     6  ...     0.000183     True              0.269617
# 2                     6  ...     0.000142     True              0.205121
# 3                     6  ...     0.000114     True              0.182630
# 4                     6  ...     0.000153     True              0.184205
# ..                  ...  ...          ...      ...                   ...
# 177                   5  ...     0.000044     True              0.142486
# 178                   6  ...     0.000583     True              0.172448
# 179                   6  ...     0.000014     True              0.133543
# 180                   6  ...     0.080201     True              0.184718
# 181                   6  ...     0.080201     True              0.129046
#
#     Percent_Replicating                         channel_names  \
# 0             60.000000      Actin, DNA, ER, Golgi, Mito, RNA
# 1             62.222222      Actin, DNA, ER, Golgi, Mito, RNA
# 2             66.666667      Actin, DNA, ER, Golgi, Mito, RNA
# 3             57.777778      Actin, DNA, ER, Golgi, Mito, RNA
# 4             67.777778      Actin, DNA, ER, Golgi, Mito, RNA
# ..                  ...                                   ...
# 177           61.111111               AGP, DNA, ER, Mito, RNA
# 178           56.666667  AGP, BrightField, DNA, ER, Mito, RNA
# 179           56.666667  AGP, BrightField, DNA, ER, Mito, RNA
# 180           48.888889  AGP, BrightField, DNA, ER, Mito, RNA
# 181           40.000000  AGP, BrightField, DNA, ER, Mito, RNA
#
#      brightfield_z_plane_used                feature_channels_found  \
# 0                         NaN      Actin, DNA, ER, Golgi, Mito, RNA
# 1                         NaN      Actin, DNA, ER, Golgi, Mito, RNA
# 2                         NaN      Actin, DNA, ER, Golgi, Mito, RNA
# 3                         NaN      Actin, DNA, ER, Golgi, Mito, RNA
# 4                         NaN      Actin, DNA, ER, Golgi, Mito, RNA
# ..                        ...                                   ...
# 177                       NaN               AGP, DNA, ER, Mito, RNA
# 178                       Z08  AGP, BrightField, DNA, ER, Mito, RNA
# 179                       Z17  AGP, BrightField, DNA, ER, Mito, RNA
# 180                       Z08  AGP, BrightField, DNA, ER, Mito, RNA
# 181                       Z08  AGP, BrightField, DNA, ER, Mito, RNA
#
#      Percent_Matching  value_95_matching  cell_count
# 0           23.255814           0.288099     2014937
# 1           18.604651           0.398249     2413350
# 2           23.255814           0.363114     2381443
# 3           18.604651           0.279178      527841
# 4           23.255814           0.291127     1101611
# ..                ...                ...         ...
# 177         18.604651           0.209276      543826
# 178         18.604651           0.232543      489099
# 179         18.604651           0.192271      452567
# 180         18.604651           0.213713      116595
# 181         20.930233           0.125624       30300
#
# [182 rows x 28 columns]

# %%
# A

group = "Magnification"

df_subset = match_rep_df[
                        (match_rep_df["sphering"] == True) &
                        (~match_rep_df["Batch"].str.contains("siteSub")) 
                        ]

group_df = utilssphering.find_group_avg_df(df_subset, group)

fig, ax = plt.subplots(figsize=(5,5))

utilssphering.group_plot(
    df_subset, 
    x="Percent_Matching", 
    y="Percent_Replicating", 
    group=group, 
    fig=fig, 
    ax_=ax, 
    legend=True,
    legend_location="lower right",
    legend_title=group,
    alpha=0.5,
    use_markers=True,
    s=70,
    x_lim=[16,26],
    y_lim=[38,70],
    xlabel="Percent Matching",
    ylabel="Percent Replicating"
    )

fig.savefig("(A)-rep-vs-match-mag.png", dpi=300)

# %%
# B 

group = "sites"

df_subset = match_rep_df[
                        (match_rep_df["sphering"] == True) &
                        (~match_rep_df["Batch"].str.contains("siteSub")) 
                        ]

group_df = utilssphering.find_group_avg_df(df_subset, group)

fig, ax = plt.subplots(figsize=(5,5))

utilssphering.group_plot(
    df_subset, 
    x="Percent_Matching", 
    y="Percent_Replicating", 
    group=group, 
    fig=fig, 
    ax_=ax, 
    legend=True,
    legend_title="Number of Sites",
    legend_location="lower right",
    alpha=0.5,
    use_markers=True,
    s=50,
    x_lim=[16,26],
    y_lim=[38,70],
    # plot_title="Number of Sites",
    xlabel="Percent Matching",
    ylabel="Percent Replicating"
    )

fig.savefig("(B)-rep-vs-match-sites.png", dpi=300)

# %%
# C

group = "Magnification"

df_subset = match_rep_df[
    (match_rep_df["sphering"] == True)
    ]

additional_cols = {
    "col1": ["cell_count", "Mean_Cell_Count", lambda x: np.mean(x)],
    "col2": ["cell_count", "SD_Cell_Count", lambda z: float('%.3f'%np.std(z))]
}
group_df = utilssphering.find_group_avg_df(df_subset, group, add_cols=additional_cols)

fig, ax = plt.subplots(figsize=(5,5))

utilssphering.group_plot(
    df_subset, 
    x="cell_count", 
    y="Percent_Replicating", 
    group=group, 
    fig=fig, 
    ax_=ax, 
    legend=True,
    legend_title=group,
    alpha=0.5,
    y_lim=[38,70],
    xlabel="Cell Count",
    ylabel="Percent Replicating"
    )


fig.savefig("(C)-rep-vs-cell_count-mag.png", dpi=300)

# %%
# D

group = "sites"

df_subset = match_rep_df[(match_rep_df["sphering"] == True)]

additional_cols = {
    "col1": ["cell_count", "Mean_Cell_Count", lambda x: np.mean(x)],
    "col2": ["cell_count", "SD_Cell_Count", lambda z: float('%.3f'%np.std(z))]
}

fig, ax = plt.subplots(figsize=(5,5))

utilssphering.group_plot(
    df_subset, 
    x="cell_count", 
    y="Percent_Replicating", 
    group=group, 
    fig=fig, 
    ax_=ax, 
    legend=True,
    legend_title="Number of Sites",
    legend_location="lower right",
    alpha=0.5,
    y_lim=[38,70],
    xlabel="Cell Count",
    ylabel="Percent Replicating"
)

fig.savefig("(D)-rep-vs-cell_count-sites.png", dpi=300)
