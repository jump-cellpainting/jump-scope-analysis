# %%
import sys
sys.path.append("../../../") # Where to find utilssphering
import utilssphering
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Read CSV
match_rep_df = pd.read_csv("../../../checkpoints/match_rep_df.csv")
match_rep_df
# Out:
#           Vendor                                              Batch  \
# 0         MolDev                                  Scope1_MolDev_10X
# 1         MolDev                                  Scope1_MolDev_10X
# 2         MolDev                                  Scope1_MolDev_10X
# 3         MolDev                                  Scope1_MolDev_10X
# 4         MolDev                           Scope1_MolDev_10X_4siteZ
# ..           ...                                                ...
# 357  Yokogawa_US  4siteSubSample_Scope1_Yokogawa_US_20X_6Ch_BRO0...
# 358  Yokogawa_US  4siteSubSample_Scope1_Yokogawa_US_20X_6Ch_BRO0...
# 359  Yokogawa_US  4siteSubSample_Scope1_Yokogawa_US_20X_6Ch_BRO0...
# 360  Yokogawa_US   4siteSubSample_Scope1_Yokogawa_US_40X_BRO0117059
# 361  Yokogawa_US   4siteSubSample_Scope1_Yokogawa_US_40X_BRO0117059
#
#                  Plate_Map_Name                Assay_Plate_Barcode  Modality  \
# 0    JUMP-MOA_compound_platemap         Plate2_PCO_6ch_4site_10XPA  Confocal
# 1    JUMP-MOA_compound_platemap         Plate2_PCO_6ch_4site_10XPA  Confocal
# 2    JUMP-MOA_compound_platemap   Plate3_PCO_6ch_4site_10XPA_Crest  Confocal
# 3    JUMP-MOA_compound_platemap   Plate3_PCO_6ch_4site_10XPA_Crest  Confocal
# 4    JUMP-MOA_compound_platemap  Plate3_PCO_6ch_4site_10XPA_Crestz  Confocal
# ..                          ...                                ...       ...
# 357  JUMP-MOA_compound_platemap                     BRO0117059_20X  Confocal
# 358  JUMP-MOA_compound_platemap                    BRO01177034_20x  Confocal
# 359  JUMP-MOA_compound_platemap                    BRO01177034_20x  Confocal
# 360  JUMP-MOA_compound_platemap                     BRO0117059_40x  Confocal
# 361  JUMP-MOA_compound_platemap                     BRO0117059_40x  Confocal
#
#      Images_per_well  Sites-SubSampled  Binning  Magnification  \
# 0                  4               NaN        1             10
# 1                  4               NaN        1             10
# 2                  4               NaN        1             10
# 3                  4               NaN        1             10
# 4                  4               NaN        1             10
# ..               ...               ...      ...            ...
# 357                9               4.0        1             20
# 358                9               4.0        1             20
# 359                9               4.0        1             20
# 360                9               4.0        1             40
# 361                9               4.0        1             40
#
#      Number_of_channels  ...  Size_MB_std  \
# 0                     6  ...     0.000144
# 1                     6  ...     0.000144
# 2                     6  ...     0.000183
# 3                     6  ...     0.000183
# 4                     6  ...     0.000142
# ..                  ...  ...          ...
# 357                   6  ...     0.000583
# 358                   6  ...     0.000014
# 359                   6  ...     0.000014
# 360                   6  ...     0.080201
# 361                   6  ...     0.080201
#
#                             channel_names brightfield_z_plane_used  \
# 0        Actin, DNA, ER, Golgi, Mito, RNA                      NaN
# 1        Actin, DNA, ER, Golgi, Mito, RNA                      NaN
# 2        Actin, DNA, ER, Golgi, Mito, RNA                      NaN
# 3        Actin, DNA, ER, Golgi, Mito, RNA                      NaN
# 4        Actin, DNA, ER, Golgi, Mito, RNA                      NaN
# ..                                    ...                      ...
# 357  AGP, BrightField, DNA, ER, Mito, RNA                      Z08
# 358  AGP, BrightField, DNA, ER, Mito, RNA                      Z17
# 359  AGP, BrightField, DNA, ER, Mito, RNA                      Z17
# 360  AGP, BrightField, DNA, ER, Mito, RNA                      Z08
# 361  AGP, BrightField, DNA, ER, Mito, RNA                      Z08
#
#                    feature_channels_found sphering value_95_replicating  \
# 0        Actin, DNA, ER, Golgi, Mito, RNA     True             0.200046
# 1        Actin, DNA, ER, Golgi, Mito, RNA    False             0.420650
# 2        Actin, DNA, ER, Golgi, Mito, RNA     True             0.268013
# 3        Actin, DNA, ER, Golgi, Mito, RNA    False             0.338900
# 4        Actin, DNA, ER, Golgi, Mito, RNA     True             0.205121
# ..                                    ...      ...                  ...
# 357  AGP, BrightField, DNA, ER, Mito, RNA    False             0.628379
# 358  AGP, BrightField, DNA, ER, Mito, RNA     True             0.139090
# 359  AGP, BrightField, DNA, ER, Mito, RNA    False             0.666818
# 360  AGP, BrightField, DNA, ER, Mito, RNA     True             0.193787
# 361  AGP, BrightField, DNA, ER, Mito, RNA    False             0.331777
#
#      Percent_Replicating  Percent_Matching  value_95_matching  cell_count
# 0              57.777778         20.930233           0.303191     2014937
# 1              35.555556         16.279070           0.307224     2014937
# 2              62.222222         20.930233           0.401802     2413350
# 3              47.777778         16.279070           0.411854     2413350
# 4              66.666667         23.255814           0.363114     2381443
# ..                   ...               ...                ...         ...
# 357            20.000000          6.976744           0.772160      489099
# 358            56.666667         18.604651           0.193171      452567
# 359            21.111111          9.302326           0.790813      452567
# 360            53.333333         20.930233           0.234702      116595
# 361            36.666667         13.953488           0.336164      116595
#
# [362 rows x 29 columns]

# %%
# A

group = "Magnification"

df_subset = match_rep_df[
                        (match_rep_df["sphering"] == True) &
                        (~match_rep_df["Batch"].str.contains("siteSub")) 
                        ]

group_df = utilssphering.find_group_avg_df(df_subset, group)

fig, ax = plt.subplots(figsize=(5,5))

utilssphering.group_plot(
    df=group_df,
    x="Mean_Percent_Matching", 
    y="Mean_Percent_Replicating",
    group=group,
    error_x="SD_Percent_Matching",
    error_y="SD_Percent_Replicating",
    fig=fig,
    ax_=ax
)
utilssphering.group_plot(
    df_subset, 
    "Percent_Matching", 
    "Percent_Replicating", 
    group=group, 
    fig=fig, 
    ax_=ax, 
    legend=True,
    alpha=0.5
    )

fig.savefig("(A)-rep-vs-match-mag.png", dpi=300)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# B 

group = "sites"

df_subset = match_rep_df[
                        (match_rep_df["sphering"] == True) &
                        (~match_rep_df["Batch"].str.contains("siteSub")) 
                        ]

group_df = utilssphering.find_group_avg_df(df_subset, group)

fig, ax = plt.subplots(figsize=(5,5))

utilssphering.group_plot(
    df=group_df,
    x="Mean_Percent_Matching", 
    y="Mean_Percent_Replicating",
    group=group,
    error_x="SD_Percent_Matching",
    error_y="SD_Percent_Replicating",
    fig=fig,
    ax_=ax
)
utilssphering.group_plot(
    df_subset, 
    "Percent_Matching", 
    "Percent_Replicating", 
    group=group, 
    fig=fig, 
    ax_=ax, 
    legend=True,
    alpha=0.5
    )

fig.savefig("(B)-rep-vs-match-sites.png", dpi=300)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /Users/ctromans/image-analysis/jump_scope/jump-scope-analysis/notebooks/figures/figure1/figure1.ipynb Cell 5 in <cell line: 5>()
#       <a href='vscode-notebook-cell:/Users/ctromans/image-analysis/jump_scope/jump-scope-analysis/notebooks/figures/figure1/figure1.ipynb#W3sZmlsZQ%3D%3D?line=0'>1</a> # B
#       <a href='vscode-notebook-cell:/Users/ctromans/image-analysis/jump_scope/jump-scope-analysis/notebooks/figures/figure1/figure1.ipynb#W3sZmlsZQ%3D%3D?line=2'>3</a> group = ["magnification", "z_planes"]
# ----> <a href='vscode-notebook-cell:/Users/ctromans/image-analysis/jump_scope/jump-scope-analysis/notebooks/figures/figure1/figure1.ipynb#W3sZmlsZQ%3D%3D?line=4'>5</a> df_subset = match_rep_df[
#       <a href='vscode-notebook-cell:/Users/ctromans/image-analysis/jump_scope/jump-scope-analysis/notebooks/figures/figure1/figure1.ipynb#W3sZmlsZQ%3D%3D?line=5'>6</a>                         (match_rep_df["sphering"] == True) &
#       <a href='vscode-notebook-cell:/Users/ctromans/image-analysis/jump_scope/jump-scope-analysis/notebooks/figures/figure1/figure1.ipynb#W3sZmlsZQ%3D%3D?line=6'>7</a>                         (~match_rep_df["Batch"].str.contains("siteSub"))
#       <a href='vscode-notebook-cell:/Users/ctromans/image-analysis/jump_scope/jump-scope-analysis/notebooks/figures/figure1/figure1.ipynb#W3sZmlsZQ%3D%3D?line=7'>8</a>                         ]
#      <a href='vscode-notebook-cell:/Users/ctromans/image-analysis/jump_scope/jump-scope-analysis/notebooks/figures/figure1/figure1.ipynb#W3sZmlsZQ%3D%3D?line=9'>10</a> group_df = utilssphering.find_group_avg_df(df_subset, group)
#      <a href='vscode-notebook-cell:/Users/ctromans/image-analysis/jump_scope/jump-scope-analysis/notebooks/figures/figure1/figure1.ipynb#W3sZmlsZQ%3D%3D?line=11'>12</a> fig, ax = plt.subplots(figsize=(5,5))
#
# NameError: name 'match_rep_df' is not defined

# %%
# C

group = "Magnification"

df_subset = match_rep_df[
    (match_rep_df["sphering"] == True)
    # & (~match_rep_df["Vendor"].str.contains("PE"))
    ]

additional_cols = {
    "col1": ["cell_count", "Mean_Cell_Count", lambda x: np.mean(x)],
    "col2": ["cell_count", "SD_Cell_Count", lambda z: float('%.3f'%np.std(z))]
}
group_df = utilssphering.find_group_avg_df(df_subset, group, add_cols=additional_cols)

fig, ax = plt.subplots(figsize=(5,5))

utilssphering.group_plot(
    df=group_df, 
    x="Mean_Cell_Count", 
    y="Mean_Percent_Replicating",
    group=group,
    error_x="SD_Cell_Count",
    error_y="SD_Percent_Replicating",
    fig=fig,
    ax_=ax
)
utilssphering.group_plot(
    df_subset, 
    "cell_count", 
    "Percent_Replicating", 
    group=group, 
    fig=fig, 
    ax_=ax, 
    legend=True)


fig.savefig("(C)-rep-vs-cell_count-mag.png", dpi=300)

# %%
# D

group = "sites"

df_subset = match_rep_df[(match_rep_df["sphering"] == True)]

additional_cols = {
    "col1": ["cell_count", "Mean_Cell_Count", lambda x: np.mean(x)],
    "col2": ["cell_count", "SD_Cell_Count", lambda z: float('%.3f'%np.std(z))]
}

fig, ax = plt.subplots(figsize=(5,5))

utilssphering.group_plot(
    df_subset, 
    "cell_count", 
    "Percent_Replicating", 
    group=group, 
    fig=fig, 
    ax_=ax, 
    legend=True)

fig.savefig("(D)-rep-vs-cell_count-sites.png", dpi=300)

# %%
# A

# group = ["Magnification", "z_plane"]
group = "Magnification"

df_subset = match_rep_df[
                        (match_rep_df["sphering"] == True) &
                        (~match_rep_df["Batch"].str.contains("siteSub")) 
                        ]

group_df = utilssphering.find_group_avg_df(df_subset, group)

fig, ax = plt.subplots(figsize=(5,5))

# utilssphering.group_plot(
#     df=group_df,
#     # x="z_plane", 
#     y="Mean_Percent_Replicating",
#     group=group,
#     # error_x="SD_Percent_Matching",
#     error_y="SD_Percent_Replicating",
#     fig=fig,
#     ax_=ax
# )
utilssphering.group_plot(
    df_subset, 
    "z_plane", 
    "Percent_Replicating", 
    group=group, 
    fig=fig, 
    ax_=ax, 
    legend=True,
    alpha=0.5
    )

# fig.savefig("(A)-rep-vs-match-mag.png", dpi=300)
