# %%
import sys
sys.path.append("../../../") # Where to find utilssphering
import utilssphering
import pandas as pd
import matplotlib.pyplot as plt

# %%
evalzoo_combined = pd.read_parquet("../../../data/evalzoo_metrics_combined.paraquet")
evalzoo_combined
# Out:
#                                                   Batch  \
# 0                                     Scope1_MolDev_10X
# 1                                     Scope1_MolDev_10X
# 2                                     Scope1_MolDev_10X
# 3                                     Scope1_MolDev_10X
# 4                                     Scope1_MolDev_10X
# ...                                                 ...
# 24635  4siteSubSample_Scope1_Yokogawa_US_40X_BRO0117059
# 24636  4siteSubSample_Scope1_Yokogawa_US_40X_BRO0117059
# 24637  4siteSubSample_Scope1_Yokogawa_US_40X_BRO0117059
# 24638  4siteSubSample_Scope1_Yokogawa_US_40X_BRO0117059
# 24639  4siteSubSample_Scope1_Yokogawa_US_40X_BRO0117059
#
#                          Metadata_Plate Metadata_pert_iname  \
# 0            Plate2_PCO_6ch_4site_10XPA               A-366
# 1      Plate3_PCO_6ch_4site_10XPA_Crest               A-366
# 2            Plate2_PCO_6ch_4site_10XPA             ABT-737
# 3      Plate3_PCO_6ch_4site_10XPA_Crest             ABT-737
# 4            Plate2_PCO_6ch_4site_10XPA             AMG-925
# ...                                 ...                 ...
# 24635                    BRO0117059_40x                None
# 24636                    BRO0117059_40x                None
# 24637                    BRO0117059_40x                None
# 24638                    BRO0117059_40x                None
# 24639                    BRO0117059_40x                None
#
#       Metadata_reference_or_other  sim_scaled_mean_i_mean_i  \
# 0                            pert                  0.017355
# 1                            pert                  0.017355
# 2                            pert                  1.550364
# 3                            pert                  1.550364
# 4                            pert                  2.544456
# ...                           ...                       ...
# 24635                        pert                  0.017382
# 24636                        pert                 -0.232787
# 24637                        pert                 -1.010539
# 24638                        pert                 -1.011224
# 24639                        pert                  2.373177
#
#        sim_scaled_mean_i_median_i  sim_scaled_median_i_mean_i  \
# 0                        0.034813                   -0.152331
# 1                        0.034813                   -0.152331
# 2                        1.901986                    1.559669
# 3                        1.901986                    1.559669
# 4                        2.651249                    2.358491
# ...                           ...                         ...
# 24635                    0.017382                    0.017382
# 24636                   -0.232787                   -0.232787
# 24637                   -1.010539                   -1.010539
# 24638                   -1.011224                   -1.011224
# 24639                    2.373177                    2.373177
#
#        sim_scaled_median_i_median_i  sim_ranked_relrank_mean_i_mean_i  \
# 0                         -0.183784                          0.505952
# 1                         -0.183784                          0.505952
# 2                          1.654185                          0.158854
# 3                          1.654185                          0.158854
# 4                          2.587136                          0.101935
# ...                             ...                               ...
# 24635                      0.017382                          0.426136
# 24636                     -0.232787                          0.585227
# 24637                     -1.010539                          0.869318
# 24638                     -1.011224                          0.710227
# 24639                      2.373177                          0.022727
#
#        sim_ranked_relrank_mean_i_median_i  ...  \
# 0                                0.531250  ...
# 1                                0.531250  ...
# 2                                0.126488  ...
# 3                                0.126488  ...
# 4                                0.093750  ...
# ...                                   ...  ...
# 24635                            0.426136  ...
# 24636                            0.585227  ...
# 24637                            0.869318  ...
# 24638                            0.710227  ...
# 24639                            0.022727  ...
#
#        sim_retrieval_r_precision_i_median_i  \
# 0                                  0.142857
# 1                                  0.142857
# 2                                  0.571429
# 3                                  0.571429
# 4                                  0.714286
# ...                                     ...
# 24635                              0.000000
# 24636                              0.000000
# 24637                              0.000000
# 24638                              0.000000
# 24639                              0.500000
#
#        sim_retrieval_average_precision_i_nlog10pvalue_mean_i  \
# 0                                               0.333687
# 1                                               0.333687
# 2                                               2.727806
# 3                                               2.727806
# 4                                               3.290924
# ...                                                  ...
# 24635                                           0.406356
# 24636                                           0.308816
# 24637                                           0.087009
# 24638                                           0.212973
# 24639                                           2.821076
#
#        sim_retrieval_average_precision_i_nlog10pvalue_median_i  \
# 0                                               0.277463
# 1                                               0.277463
# 2                                               3.008908
# 3                                               3.008908
# 4                                               4.000043
# ...                                                  ...
# 24635                                           0.406356
# 24636                                           0.308816
# 24637                                           0.087009
# 24638                                           0.212973
# 24639                                           2.821076
#
#        sim_retrieval_average_precision_i_nlog10qvalue_mean_i       Vendor  \
# 0                                               0.308864           MolDev
# 1                                               0.308864           MolDev
# 2                                               2.293433           MolDev
# 3                                               2.293433           MolDev
# 4                                               2.591954           MolDev
# ...                                                  ...              ...
# 24635                                           0.126677      Yokogawa_US
# 24636                                           0.090321      Yokogawa_US
# 24637                                           0.055154      Yokogawa_US
# 24638                                           0.063732      Yokogawa_US
# 24639                                           1.488638      Yokogawa_US
#
#        Magnification  Binning  z_plane  metric_type  \
# 0                 10        1        1          ref
# 1                 10        1        1          ref
# 2                 10        1        1          ref
# 3                 10        1        1          ref
# 4                 10        1        1          ref
# ...              ...      ...      ...          ...
# 24635             40        1       12      non_rep
# 24636             40        1       12      non_rep
# 24637             40        1       12      non_rep
# 24638             40        1       12      non_rep
# 24639             40        1       12      non_rep
#
#                                      Metadata_moa
# 0                                            None
# 1                                            None
# 2                                            None
# 3                                            None
# 4                                            None
# ...                                           ...
# 24635     pyruvate dehydrogenase kinase inhibitor
# 24636                 smoothened receptor agonist
# 24637                    tricyclic antidepressant
# 24638  tumor necrosis factor production inhibitor
# 24639       ubiquitin specific protease inhibitor
#
# [24640 rows x 37 columns]

# %%
metric_type = "ref"
x = "Binning"
y = "sim_retrieval_average_precision_i_mean_i"

plot_df = evalzoo_combined[
    (evalzoo_combined["Vendor"] == "PE") &
    (~evalzoo_combined["Batch"].str.contains("siteSub"))
]

plot_df = plot_df[plot_df["metric_type"] == metric_type].groupby(["Metadata_pert_iname", x]).mean().reset_index()

fig, ax = plt.subplots(figsize=(5,5))

utilssphering.plot_two_distributions(
    plot_df,
    x,
    y,
    xlabel="Detector Binning",
    ylabel="Mean Average Precision\n(Finding Replicates)",
    ax=ax,
    fig=fig
)

fig.savefig("(S4A)-mAP_replicates-vs-detector_binning.png", dpi=300)
# Out:
# The pvalue is: 0.8726657710709493
# The pvalue is: 0.8726657710709493

# %%
metric_type = "non_rep"
x = "Binning"
group1, group2 = 1, 2
y = "sim_retrieval_average_precision_i_mean_i"

plot_df = evalzoo_combined[
    (evalzoo_combined["Vendor"] == "PE") &
    (~evalzoo_combined["Batch"].str.contains("siteSub"))
]

plot_df = plot_df[plot_df["metric_type"] == metric_type].groupby(["Metadata_moa", x]).mean().reset_index()

fig, ax = plt.subplots(figsize=(5,5))

utilssphering.plot_two_distributions(
    plot_df,
    x,
    y,
    xlabel="Detector Binning",
    ylabel="Mean Average Precision\n(Finding MoA Matches)",
    ax=ax,
    fig=fig
)

fig.savefig("(S4B)-mAP_matches-vs-detector_binning.png", dpi=300)
# Out:
# The pvalue is: 0.8214063792265887
# The pvalue is: 0.8214063792265887

# %%
metric_type = "ref"
x = "z_plane"
y = "sim_retrieval_average_precision_i_mean_i"

plot_df = evalzoo_combined[
    (evalzoo_combined["Vendor"] == "PE") &
    (~evalzoo_combined["Batch"].str.contains("siteSub"))
]

plot_df = plot_df[plot_df["metric_type"] == metric_type].groupby(["Metadata_pert_iname", x]).mean().reset_index()

fig, ax = plt.subplots(figsize=(5,5))

utilssphering.plot_two_distributions(
    plot_df,
    x,
    y,
    xlabel="Number of Z planes",
    ylabel="Mean Average Precision\n(Finding MoA Replicates)",
    ax=ax,
    fig=fig
)

fig.savefig("(S4C)-mAP_replicates-vs-z_planes.png", dpi=300)
# Out:
# The pvalue is: 0.7455808926930223
# The pvalue is: 0.7455808926930223

# %%
metric_type = "non_rep"
x = "z_plane"
y = "sim_retrieval_average_precision_i_mean_i"

plot_df = evalzoo_combined[
    (evalzoo_combined["Vendor"] == "PE") &
    (~evalzoo_combined["Batch"].str.contains("siteSub"))
]

plot_df = plot_df[plot_df["metric_type"] == metric_type].groupby(["Metadata_moa", x]).mean().reset_index()

fig, ax = plt.subplots(figsize=(5,5))

utilssphering.plot_two_distributions(
    plot_df,
    x,
    y,
    xlabel="Number of Z planes",
    ylabel="Mean Average Precision\n(Finding MoA Matches)",
    ax=ax,
    fig=fig
)

fig.savefig("(S4D)-mAP_matches-vs-z_planes.png", dpi=300)
# Out:
# The pvalue is: 0.7440245155236642
# The pvalue is: 0.7440245155236642
