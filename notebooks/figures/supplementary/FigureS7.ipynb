# %%
import pycytominer
import matplotlib.pyplot as plt
import pandas as pd
import os
import yaml
import shutil
import sys
sys.path.append("../../../")
import utilssphering

# %% [markdown]
# 1. Drop features from profile_normalized_negcon.csv.gz.csv.gz
# 2. Perform feature selection
# 3. Save this feature selected feature dropped profiles into a new dir
# 4. Create an evalzoo params file for this dropped profile
# 5. Run evalzoo
# 6. plot the mAP for the non-dropped evalzoo paraquet file vs the dropped evalzoo paraquet

# %%
match_rep_df = pd.read_csv("../../../checkpoints/match_rep_df.csv")
match_rep_df = match_rep_df[
    (~match_rep_df["Batch"].str.contains("siteSub")) &
    (match_rep_df["channel_names"].str.contains("RNA"))
    ]
match_rep_df
# Out:
#           Vendor                                   Batch  \
# 0         MolDev                       Scope1_MolDev_10X
# 1         MolDev                       Scope1_MolDev_10X
# 2         MolDev                       Scope1_MolDev_10X
# 3         MolDev                       Scope1_MolDev_10X
# 4         MolDev                Scope1_MolDev_10X_4siteZ
# ..           ...                                     ...
# 103  Yokogawa_US   Scope1_Yokogawa_US_20X_6Ch_BRO0117059
# 104  Yokogawa_US  Scope1_Yokogawa_US_20X_6Ch_BRO01177034
# 105  Yokogawa_US  Scope1_Yokogawa_US_20X_6Ch_BRO01177034
# 106  Yokogawa_US       Scope1_Yokogawa_US_40X_BRO0117059
# 107  Yokogawa_US       Scope1_Yokogawa_US_40X_BRO0117059
#
#                  Plate_Map_Name                Assay_Plate_Barcode   Modality  \
# 0    JUMP-MOA_compound_platemap         Plate2_PCO_6ch_4site_10XPA  Widefield
# 1    JUMP-MOA_compound_platemap         Plate2_PCO_6ch_4site_10XPA  Widefield
# 2    JUMP-MOA_compound_platemap   Plate3_PCO_6ch_4site_10XPA_Crest   Confocal
# 3    JUMP-MOA_compound_platemap   Plate3_PCO_6ch_4site_10XPA_Crest   Confocal
# 4    JUMP-MOA_compound_platemap  Plate3_PCO_6ch_4site_10XPA_Crestz   Confocal
# ..                          ...                                ...        ...
# 103  JUMP-MOA_compound_platemap                     BRO0117059_20X   Confocal
# 104  JUMP-MOA_compound_platemap                    BRO01177034_20x   Confocal
# 105  JUMP-MOA_compound_platemap                    BRO01177034_20x   Confocal
# 106  JUMP-MOA_compound_platemap                     BRO0117059_40x   Confocal
# 107  JUMP-MOA_compound_platemap                     BRO0117059_40x   Confocal
#
#      Images_per_well  Sites-SubSampled  Binning  Magnification  \
# 0                  4               NaN        1             10
# 1                  4               NaN        1             10
# 2                  4               NaN        1             10
# 3                  4               NaN        1             10
# 4                  4               NaN        1             10
# ..               ...               ...      ...            ...
# 103                9               NaN        1             20
# 104                9               NaN        1             20
# 105                9               NaN        1             20
# 106                9               NaN        1             40
# 107                9               NaN        1             40
#
#      Number_of_channels  ...  Size_MB_std sphering  value_95_replicating  \
# 0                     6  ...     0.000144     True              0.191908
# 1                     6  ...     0.000144    False              0.269727
# 2                     6  ...     0.000183     True              0.269617
# 3                     6  ...     0.000183    False              0.329074
# 4                     6  ...     0.000142     True              0.205121
# ..                  ...  ...          ...      ...                   ...
# 103                   6  ...     0.000583    False              0.407403
# 104                   6  ...     0.000014     True              0.206867
# 105                   6  ...     0.000014    False              0.261967
# 106                   6  ...     0.080201     True              0.181967
# 107                   6  ...     0.080201    False              0.370124
#
#     Percent_Replicating                         channel_names  \
# 0             60.000000      Actin, DNA, ER, Golgi, Mito, RNA
# 1             53.333333      Actin, DNA, ER, Golgi, Mito, RNA
# 2             62.222222      Actin, DNA, ER, Golgi, Mito, RNA
# 3             45.555556      Actin, DNA, ER, Golgi, Mito, RNA
# 4             66.666667      Actin, DNA, ER, Golgi, Mito, RNA
# ..                  ...                                   ...
# 103           56.666667  AGP, BrightField, DNA, ER, Mito, RNA
# 104           58.888889  AGP, BrightField, DNA, ER, Mito, RNA
# 105           54.444444  AGP, BrightField, DNA, ER, Mito, RNA
# 106           54.444444  AGP, BrightField, DNA, ER, Mito, RNA
# 107           45.555556  AGP, BrightField, DNA, ER, Mito, RNA
#
#      brightfield_z_plane_used                feature_channels_found  \
# 0                         NaN      Actin, DNA, ER, Golgi, Mito, RNA
# 1                         NaN      Actin, DNA, ER, Golgi, Mito, RNA
# 2                         NaN      Actin, DNA, ER, Golgi, Mito, RNA
# 3                         NaN      Actin, DNA, ER, Golgi, Mito, RNA
# 4                         NaN      Actin, DNA, ER, Golgi, Mito, RNA
# ..                        ...                                   ...
# 103                       Z08  AGP, BrightField, DNA, ER, Mito, RNA
# 104                       Z17  AGP, BrightField, DNA, ER, Mito, RNA
# 105                       Z17  AGP, BrightField, DNA, ER, Mito, RNA
# 106                       Z08  AGP, BrightField, DNA, ER, Mito, RNA
# 107                       Z08  AGP, BrightField, DNA, ER, Mito, RNA
#
#      Percent_Matching  value_95_matching  cell_count
# 0           23.255814           0.288099     2014937
# 1           18.604651           0.320855     2014937
# 2           18.604651           0.398249     2413350
# 3           18.604651           0.389170     2413350
# 4           23.255814           0.363114     2381443
# ..                ...                ...         ...
# 103         20.930233           0.480152     1136319
# 104         18.604651           0.318081     1045379
# 105         20.930233           0.360108     1045379
# 106         18.604651           0.266650      279900
# 107         13.953488           0.455924      279900
#
# [94 rows x 28 columns]

# %%
def do_feature_select(plate_df):
    """
    Find the column names that are CellProfiler features. Eg. column names
    that start with "Nuclei" or "Cytoplasm"
    """
    feature_select_features = pycytominer.cyto_utils.infer_cp_features(
        plate_df
    )
    # For all of the cellprofiler features, perform these operations on them
    return pycytominer.feature_select(
        profiles=plate_df,
        features=feature_select_features,
        operation=['variance_threshold','correlation_threshold',
        'drop_na_columns','blocklist']
    )

# %%
profile_parent_dir = "../../../profiles"
parent_save_dir = profile_parent_dir + "_RNA_dropped"

if not os.path.exists(parent_save_dir):
     os.makedirs(parent_save_dir)

for ind, a_vendor in enumerate(match_rep_df["Vendor"].unique()):
        print(f"Processing {a_vendor}")
        vendor_data = match_rep_df.loc[match_rep_df["Vendor"] == a_vendor]
        for a_batch in vendor_data["Batch"].unique():
            batch_data = vendor_data.loc[vendor_data["Batch"] == a_batch]
            for a_plate in batch_data["Assay_Plate_Barcode"].unique():
                # plate_data = batch_data.loc[batch_data["Assay_Plate_Barcode"] == a_plate]
                data_path = os.path.join(profile_parent_dir, a_batch, a_plate, a_plate+"_normalized_negcon.csv.gz")
                load_data = pd.read_csv(data_path)
                drop_cols = "RNA"
                input_columns = load_data.columns
                col_list = [x for x in input_columns if drop_cols not in x]
                try:
                    dropped_df = pd.DataFrame(load_data[col_list])
                    feature_selected_df = do_feature_select(dropped_df)
                except Exception as e:
                    print(f"Error: {e}")

                profile_save_path = os.path.join(parent_save_dir, a_batch, a_plate)

                if not os.path.exists(profile_save_path):
                    os.makedirs(profile_save_path)

                feature_selected_df.to_csv(os.path.join(profile_save_path, a_plate+"_normalized_feature_select_negcon_batch.csv.gz"))

# %%
# Check that RNA features were indeed dropped
df = pd.read_csv("../../../profiles_RNA_dropped/Scope1_MolDev_10X/Plate2_PCO_6ch_4site_10XPA/Plate2_PCO_6ch_4site_10XPA_normalized_feature_select_negcon_batch.csv.gz")

[col for col in df.columns if "RNA" in col]
# Out:
# []

# %%
match_rep_df = pd.read_csv("../../../checkpoints/match_rep_df.csv")
match_rep_df = match_rep_df[
    (~match_rep_df["Batch"].str.contains("siteSub")) &
    (match_rep_df["channel_names"].str.contains("Brightfield", case=False))
    ]
match_rep_df
# Out:
#           Vendor                                   Batch  \
# 94   Yokogawa_US                  Scope1_Yokogawa_US_10X
# 95   Yokogawa_US                  Scope1_Yokogawa_US_10X
# 102  Yokogawa_US   Scope1_Yokogawa_US_20X_6Ch_BRO0117059
# 103  Yokogawa_US   Scope1_Yokogawa_US_20X_6Ch_BRO0117059
# 104  Yokogawa_US  Scope1_Yokogawa_US_20X_6Ch_BRO01177034
# 105  Yokogawa_US  Scope1_Yokogawa_US_20X_6Ch_BRO01177034
# 106  Yokogawa_US       Scope1_Yokogawa_US_40X_BRO0117059
# 107  Yokogawa_US       Scope1_Yokogawa_US_40X_BRO0117059
#
#                  Plate_Map_Name Assay_Plate_Barcode  Modality  \
# 94   JUMP-MOA_compound_platemap      BRO0117014_10x  Confocal
# 95   JUMP-MOA_compound_platemap      BRO0117014_10x  Confocal
# 102  JUMP-MOA_compound_platemap      BRO0117059_20X  Confocal
# 103  JUMP-MOA_compound_platemap      BRO0117059_20X  Confocal
# 104  JUMP-MOA_compound_platemap     BRO01177034_20x  Confocal
# 105  JUMP-MOA_compound_platemap     BRO01177034_20x  Confocal
# 106  JUMP-MOA_compound_platemap      BRO0117059_40x  Confocal
# 107  JUMP-MOA_compound_platemap      BRO0117059_40x  Confocal
#
#      Images_per_well  Sites-SubSampled  Binning  Magnification  \
# 94                 4               NaN        1             10
# 95                 4               NaN        1             10
# 102                9               NaN        1             20
# 103                9               NaN        1             20
# 104                9               NaN        1             20
# 105                9               NaN        1             20
# 106                9               NaN        1             40
# 107                9               NaN        1             40
#
#      Number_of_channels  ...  Size_MB_std sphering  value_95_replicating  \
# 94                    6  ...     0.124906     True              0.218493
# 95                    6  ...     0.124906    False              0.287125
# 102                   6  ...     0.000583     True              0.281239
# 103                   6  ...     0.000583    False              0.407403
# 104                   6  ...     0.000014     True              0.206867
# 105                   6  ...     0.000014    False              0.261967
# 106                   6  ...     0.080201     True              0.181967
# 107                   6  ...     0.080201    False              0.370124
#
#     Percent_Replicating                         channel_names  \
# 94            56.666667  AGP, BrightField, DNA, ER, Mito, RNA
# 95            47.777778  AGP, BrightField, DNA, ER, Mito, RNA
# 102           61.111111  AGP, BrightField, DNA, ER, Mito, RNA
# 103           56.666667  AGP, BrightField, DNA, ER, Mito, RNA
# 104           58.888889  AGP, BrightField, DNA, ER, Mito, RNA
# 105           54.444444  AGP, BrightField, DNA, ER, Mito, RNA
# 106           54.444444  AGP, BrightField, DNA, ER, Mito, RNA
# 107           45.555556  AGP, BrightField, DNA, ER, Mito, RNA
#
#      brightfield_z_plane_used                feature_channels_found  \
# 94                        Z06  AGP, BrightField, DNA, ER, Mito, RNA
# 95                        Z06  AGP, BrightField, DNA, ER, Mito, RNA
# 102                       Z08  AGP, BrightField, DNA, ER, Mito, RNA
# 103                       Z08  AGP, BrightField, DNA, ER, Mito, RNA
# 104                       Z17  AGP, BrightField, DNA, ER, Mito, RNA
# 105                       Z17  AGP, BrightField, DNA, ER, Mito, RNA
# 106                       Z08  AGP, BrightField, DNA, ER, Mito, RNA
# 107                       Z08  AGP, BrightField, DNA, ER, Mito, RNA
#
#      Percent_Matching  value_95_matching  cell_count
# 94          23.255814           0.356314     2047342
# 95          18.604651           0.353686     2047342
# 102         23.255814           0.430396     1136319
# 103         20.930233           0.480152     1136319
# 104         18.604651           0.318081     1045379
# 105         20.930233           0.360108     1045379
# 106         18.604651           0.266650      279900
# 107         13.953488           0.455924      279900
#
# [8 rows x 28 columns]

# %%
profile_parent_dir = "../../../profiles"
parent_save_dir = profile_parent_dir + "_BrightField_dropped"

if not os.path.exists(parent_save_dir):
     os.makedirs(parent_save_dir)

for ind, a_vendor in enumerate(match_rep_df["Vendor"].unique()):
        print(f"Processing {a_vendor}")
        vendor_data = match_rep_df.loc[match_rep_df["Vendor"] == a_vendor]
        for a_batch in vendor_data["Batch"].unique():
            batch_data = vendor_data.loc[vendor_data["Batch"] == a_batch]
            for a_plate in batch_data["Assay_Plate_Barcode"].unique():
                # plate_data = batch_data.loc[batch_data["Assay_Plate_Barcode"] == a_plate]
                data_path = os.path.join(profile_parent_dir, a_batch, a_plate, a_plate+"_normalized_negcon.csv.gz")
                load_data = pd.read_csv(data_path)
                drop_cols = "BrightField"
                input_columns = load_data.columns
                col_list = [x for x in input_columns if drop_cols.casefold() not in x.casefold()]
                try:
                    dropped_df = pd.DataFrame(load_data[col_list])
                    feature_selected_df = do_feature_select(dropped_df)
                except Exception as e:
                    print(f"Error: {e}")

                profile_save_path = os.path.join(parent_save_dir, a_batch, a_plate)

                if not os.path.exists(profile_save_path):
                    os.makedirs(profile_save_path)

                feature_selected_df.to_csv(os.path.join(profile_save_path, a_plate+"_normalized_feature_select_negcon_batch.csv.gz"))

# %%
df = pd.read_csv("../../../profiles_BrightField_dropped/Scope1_Yokogawa_US_10X/BRO0117014_10x/BRO0117014_10x_normalized_feature_select_negcon_batch.csv.gz")

[col for col in df.columns if "BrightField" in col]
# Out:
# []

# %%
def make_params(df, drop=None):
    with open("../../../evalzoo/within_matches.yml") as f:
        match_yaml = yaml.safe_load(f)

    with open("../../../evalzoo/within_replicates.yml") as f:
        rep_yaml = yaml.safe_load(f)

    for batch, grouped_df in df.groupby("Batch")[["Batch", "Assay_Plate_Barcode"]]:
        plates = grouped_df["Assay_Plate_Barcode"].tolist()

        out_rep_yaml = rep_yaml
        out_rep_yaml["experiment"]["data_path"] = f"/input/profiles{drop if drop is not None else ''}/{batch}"
        out_rep_yaml["experiment"]["plates"] = plates

        out_match_yaml = match_yaml
        out_match_yaml["experiment"]["data_path"] = f"/input/profiles{drop if drop is not None else ''}/{batch}"
        out_match_yaml["experiment"]["plates"] = plates

        save_dir = os.path.join(f"params{drop if drop is not None else ''}", batch)

        if not os.path.exists(save_dir):
            os.makedirs(save_dir)

        with open(os.path.join(save_dir, f'{batch}_replicates_config.yaml'), 'w') as f:
            yaml.dump(out_rep_yaml, f, sort_keys=False)

        with open(os.path.join(save_dir, f'{batch}_matches_config.yaml'), 'w') as f:
            yaml.dump(out_match_yaml, f, sort_keys=False)


match_rep_df = pd.read_csv("../../../checkpoints/match_rep_df.csv")

make_params(df = match_rep_df[
    (~match_rep_df["Batch"].str.contains("siteSub")) &
    (match_rep_df["channel_names"].str.contains("RNA"))
    ],
    drop="_RNA_dropped")

make_params(df = match_rep_df[
    (~match_rep_df["Batch"].str.contains("siteSub")) &
    (match_rep_df["channel_names"].str.contains("Brightfield", case=False))
    ], 
    drop="_BrightField_dropped")

# %%
def postprocess_evalzoo(results_dir):
    for result_folder in os.listdir(results_dir):
        print(os.path.join(results_dir, result_folder))
        if ".DS_Store" not in result_folder:
            with open(os.path.join(results_dir, result_folder, "params.yaml")) as f:
                param_file = yaml.safe_load(f)
            batch = param_file["experiment"]["data_path"].split("/")[-1]
            # Don't try to process a folder that has already been processed
            if batch not in result_folder:
                os.remove(os.path.join(results_dir, result_folder, "profiles.parquet"))
                os.remove(os.path.join(results_dir, result_folder, "metrics_plot_level_1_pvalue.html"))
                os.remove(os.path.join(results_dir, result_folder, "metrics_plot_level_1_qvalue.html"))
                shutil.rmtree(os.path.join(results_dir, result_folder, "metrics_plot_level_1_pvalue_files"))
                shutil.rmtree(os.path.join(results_dir, result_folder, "metrics_plot_level_1_qvalue_files"))
                rep_or_non_rep = param_file["experiment"]["background_type"]
                shutil.move(os.path.join(results_dir, result_folder), os.path.join(results_dir, batch+"_"+rep_or_non_rep))

postprocess_evalzoo("../../../data/results_RNA_dropped/results/")
postprocess_evalzoo("../../../data/results_BrightField_dropped/results/")
# Out:
# ../../../data/results_RNA_dropped/results/a11d714a
# ../../../data/results_RNA_dropped/results/9bb3a2d4
# ../../../data/results_RNA_dropped/results/e71dd487
# ../../../data/results_RNA_dropped/results/3a496d2d
# ../../../data/results_RNA_dropped/results/85f59eec
# ../../../data/results_RNA_dropped/results/b78ef6c8
# ../../../data/results_RNA_dropped/results/ee27508b
# ../../../data/results_RNA_dropped/results/a8e60cf0
# ../../../data/results_RNA_dropped/results/00ed98f6
# ../../../data/results_RNA_dropped/results/6752f1e2
# ../../../data/results_RNA_dropped/results/b1dc5e10
# ../../../data/results_RNA_dropped/results/d44cb0e7
# ../../../data/results_RNA_dropped/results/ced2d093
# ../../../data/results_RNA_dropped/results/ba1fd411
# ../../../data/results_RNA_dropped/results/7f136e02
# ../../../data/results_RNA_dropped/results/bc2e7c7a
# ../../../data/results_RNA_dropped/results/c687108f
# ../../../data/results_RNA_dropped/results/ff632e15
# ../../../data/results_RNA_dropped/results/8fb21638
# ../../../data/results_RNA_dropped/results/a1ff3769
# ../../../data/results_RNA_dropped/results/ab08ffac
# ../../../data/results_RNA_dropped/results/b1b7147d
# ../../../data/results_RNA_dropped/results/12bf6196
# ../../../data/results_RNA_dropped/results/a0832cbc
# ../../../data/results_RNA_dropped/results/32bfcd6d
# ../../../data/results_RNA_dropped/results/18a44a11
# ../../../data/results_RNA_dropped/results/4d54c31c
# ../../../data/results_RNA_dropped/results/ee5ef333
# ../../../data/results_RNA_dropped/results/9ee71f3a
# ../../../data/results_RNA_dropped/results/a2c5ea25
# ../../../data/results_RNA_dropped/results/936f4d9d
# ../../../data/results_RNA_dropped/results/ccf3137f
# ../../../data/results_RNA_dropped/results/46939091
# ../../../data/results_RNA_dropped/results/441d8e85
# ../../../data/results_RNA_dropped/results/ff1cb8db
# ../../../data/results_RNA_dropped/results/2e2a9107
# ../../../data/results_RNA_dropped/results/4a7babfd
# ../../../data/results_RNA_dropped/results/4ac8a643
# ../../../data/results_RNA_dropped/results/67728974
# ../../../data/results_RNA_dropped/results/aee82aaf
# ../../../data/results_BrightField_dropped/results/c777ee3f
# ../../../data/results_BrightField_dropped/results/a97d50fc
# ../../../data/results_BrightField_dropped/results/e8f472bd
# ../../../data/results_BrightField_dropped/results/c7ea930a
# ../../../data/results_BrightField_dropped/results/532d7bee
# ../../../data/results_BrightField_dropped/results/487ebc3e
# ../../../data/results_BrightField_dropped/results/e3caf19d
# ../../../data/results_BrightField_dropped/results/b3fa5a4b

# %%
def combine_evalzoo_metrics(match_rep_df: pd.DataFrame, evalzoo_dir: str = "results/results"):
    # Add Batch and Metadata_Plate since we need to check the presence of a
    # string in them later, and you can't check them if they don't exist
    output_df = pd.DataFrame({"Batch": [], "Metadata_Plate": []})
    for ind, row in match_rep_df.iterrows():
        # Need to do some check that this row has not already been processed (so
        # we don't add it twice)
        if not (row["Batch"] in output_df["Batch"].values and row["Assay_Plate_Barcode"] in output_df["Metadata_Plate"].values):
            ref_metric_path = os.path.join(evalzoo_dir, row["Batch"]+"_ref", f"metrics_level_1_ref.parquet")
            non_rep_metric_path = os.path.join(evalzoo_dir, row["Batch"]+"_non_rep", f"metrics_level_1_non_rep.parquet")

            ref_metric_df = pd.read_parquet(ref_metric_path)
            non_rep_metric_df = pd.read_parquet(non_rep_metric_path)

            # Since we are going to use the metric_type to differentiate between ref
            # and non_rep, remove this information from the feature names
            # ref_metric_df = ref_metric_df.rename(lambda x: x + "_ref" if "sim_" in x else x, axis=1)
            # non_rep_metric_df = non_rep_metric_df.rename(lambda x: x + "_non_rep" if "sim_" in x else x, axis=1)

            ref_metric_df = ref_metric_df.rename(lambda x: x.replace("_ref", "") if "sim_" in x else x, axis=1)
            non_rep_metric_df = non_rep_metric_df.rename(lambda x: x.replace("_non_rep", "") if "sim_" in x else x, axis=1)

            # Add cols
            (
                ref_metric_df["Vendor"], 
                ref_metric_df["Batch"], 
                ref_metric_df["Magnification"], 
                ref_metric_df["Binning"], 
                ref_metric_df["z_plane"], 
                ref_metric_df["metric_type"]
                ) = (
                row["Vendor"], 
                row["Batch"], 
                row["Magnification"], 
                row["Binning"], 
                row["z_plane"], 
                "ref"
            )

            (
                non_rep_metric_df["Vendor"], 
                non_rep_metric_df["Batch"],
                non_rep_metric_df["Magnification"], 
                non_rep_metric_df["Binning"], 
                non_rep_metric_df["z_plane"], 
                non_rep_metric_df["metric_type"]
                ) = (
                row["Vendor"], 
                row["Batch"], 
                row["Magnification"], 
                row["Binning"], 
                row["z_plane"], 
                "non_rep"
                )
            
            # Cast some columns to int
            ref_metric_df["Magnification"] = ref_metric_df["Magnification"].astype("Int64")
            ref_metric_df["Binning"] = ref_metric_df["Binning"].astype("Int64")
            ref_metric_df["z_plane"] = ref_metric_df["z_plane"].astype("Int64")

            non_rep_metric_df["Magnification"] = non_rep_metric_df["Magnification"].astype("Int64")
            non_rep_metric_df["Binning"] = non_rep_metric_df["Binning"].astype("Int64")
            non_rep_metric_df["z_plane"] = non_rep_metric_df["z_plane"].astype("Int64")


            output_df = pd.concat([output_df, ref_metric_df, non_rep_metric_df], axis=0)

    return output_df

match_rep_df = pd.read_csv("../../../checkpoints/match_rep_df.csv")
match_rep_df = match_rep_df[
    (~match_rep_df["Batch"].str.contains("siteSub")) &
    (match_rep_df["channel_names"].str.contains("RNA"))
    ]
evalzoo_combined = combine_evalzoo_metrics(match_rep_df, "../../../data/results_RNA_dropped/results/")
evalzoo_combined.to_parquet("rna-drop-evalzoo-combined.parquet", index=False)

match_rep_df = pd.read_csv("../../../checkpoints/match_rep_df.csv")
match_rep_df = match_rep_df[
    (~match_rep_df["Batch"].str.contains("siteSub")) &
    (match_rep_df["channel_names"].str.contains("Brightfield", case=False))
    ]
evalzoo_combined = combine_evalzoo_metrics(match_rep_df, "../../../data/results_BrightField_dropped/results/")
evalzoo_combined.to_parquet("brightfield-drop-evalzoo-combined.parquet", index=False)
# Out:
# /var/folders/rw/691cc6h16f9cfxlh9g6bpq400000gq/T/ipykernel_57002/987030368.py:8: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if not (row["Batch"] in output_df["Batch"].values and row["Assay_Plate_Barcode"] in output_df["Metadata_Plate"].values):
# /var/folders/rw/691cc6h16f9cfxlh9g6bpq400000gq/T/ipykernel_57002/987030368.py:8: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if not (row["Batch"] in output_df["Batch"].values and row["Assay_Plate_Barcode"] in output_df["Metadata_Plate"].values):

# %%
all_channels_df = pd.read_parquet("../../../data/evalzoo_metrics_combined.paraquet")

brightfield_drop_df = pd.read_parquet("brightfield-drop-evalzoo-combined.parquet")

# Keep only the profiles that are tested in brightfield
subset_all_df = all_channels_df[
    (all_channels_df["Metadata_Plate"].isin(brightfield_drop_df["Metadata_Plate"])) & 
    (~all_channels_df["Batch"].str.contains("siteSub"))
     ].copy()

subset_all_df.loc[:, "dropout"] = "All Channels"
brightfield_drop_df.loc[:, "dropout"] = "No BrightField"

print(subset_all_df.shape, brightfield_drop_df.shape)

all_df = pd.concat([subset_all_df, brightfield_drop_df], axis=0)
all_df
# Out:
# (532, 38) (532, 38)
#                                   Batch  Metadata_Plate Metadata_pert_iname  \
# 6420             Scope1_Yokogawa_US_10X  BRO0117014_10x               A-366
# 6421             Scope1_Yokogawa_US_10X  BRO0117014_10x             ABT-737
# 6422             Scope1_Yokogawa_US_10X  BRO0117014_10x             AMG-925
# 6423             Scope1_Yokogawa_US_10X  BRO0117014_10x              AMG900
# 6424             Scope1_Yokogawa_US_10X  BRO0117014_10x             APY0201
# ...                                 ...             ...                 ...
# 527   Scope1_Yokogawa_US_40X_BRO0117059  BRO0117059_40x                None
# 528   Scope1_Yokogawa_US_40X_BRO0117059  BRO0117059_40x                None
# 529   Scope1_Yokogawa_US_40X_BRO0117059  BRO0117059_40x                None
# 530   Scope1_Yokogawa_US_40X_BRO0117059  BRO0117059_40x                None
# 531   Scope1_Yokogawa_US_40X_BRO0117059  BRO0117059_40x                None
#
#      Metadata_reference_or_other  sim_scaled_mean_i_mean_i  \
# 6420                        pert                 -0.212382
# 6421                        pert                  2.660274
# 6422                        pert                  3.106238
# 6423                        pert                  5.725393
# 6424                        pert                  8.303124
# ...                          ...                       ...
# 527                         pert                  0.442451
# 528                         pert                  0.534133
# 529                         pert                  0.511701
# 530                         pert                  0.553910
# 531                         pert                  0.543839
#
#       sim_scaled_mean_i_median_i  sim_scaled_median_i_mean_i  \
# 6420                   -0.023707                    0.321436
# 6421                    2.745765                    2.524185
# 6422                    3.508187                    2.629808
# 6423                    5.905127                    5.799696
# 6424                    9.022150                    8.770587
# ...                          ...                         ...
# 527                     0.442451                    0.442451
# 528                     0.534133                    0.534133
# 529                     0.511701                    0.511701
# 530                     0.553910                    0.553910
# 531                     0.543839                    0.543839
#
#       sim_scaled_median_i_median_i  sim_ranked_relrank_mean_i_mean_i  \
# 6420                      0.325855                          0.541667
# 6421                      2.584635                          0.065972
# 6422                      2.808275                          0.086806
# 6423                      5.978359                          0.041667
# 6424                      9.586999                          0.041667
# ...                            ...                               ...
# 527                       0.442451                          0.448864
# 528                       0.534133                          0.272727
# 529                       0.511701                          0.380682
# 530                       0.553910                          0.204545
# 531                       0.543839                          0.227273
#
#       sim_ranked_relrank_mean_i_median_i  ...  \
# 6420                            0.513889  ...
# 6421                            0.048611  ...
# 6422                            0.076389  ...
# 6423                            0.041667  ...
# 6424                            0.041667  ...
# ...                                  ...  ...
# 527                             0.448864  ...
# 528                             0.272727  ...
# 529                             0.380682  ...
# 530                             0.204545  ...
# 531                             0.227273  ...
#
#       sim_retrieval_average_precision_i_nlog10pvalue_mean_i  \
# 6420                                           0.369927
# 6421                                           3.284809
# 6422                                           2.881854
# 6423                                           4.000043
# 6424                                           4.000043
# ...                                                 ...
# 527                                            0.409372
# 528                                            0.710201
# 529                                            0.509829
# 530                                            0.746380
# 531                                            0.703823
#
#       sim_retrieval_average_precision_i_nlog10pvalue_median_i  \
# 6420                                           0.402050
# 6421                                           3.849528
# 6422                                           3.261483
# 6423                                           4.000043
# 6424                                           4.000043
# ...                                                 ...
# 527                                            0.409372
# 528                                            0.710201
# 529                                            0.509829
# 530                                            0.746380
# 531                                            0.703823
#
#       sim_retrieval_average_precision_i_nlog10qvalue_mean_i       Vendor  \
# 6420                                           0.288114      Yokogawa_US
# 6421                                           2.761931      Yokogawa_US
# 6422                                           2.459091      Yokogawa_US
# 6423                                           3.346831      Yokogawa_US
# 6424                                           3.346831      Yokogawa_US
# ...                                                 ...              ...
# 527                                            0.267266      Yokogawa_US
# 528                                            0.346536      Yokogawa_US
# 529                                            0.291334      Yokogawa_US
# 530                                            0.346536      Yokogawa_US
# 531                                            0.346536      Yokogawa_US
#
#       Magnification  Binning  z_plane  metric_type  \
# 6420             10        1       12          ref
# 6421             10        1       12          ref
# 6422             10        1       12          ref
# 6423             10        1       12          ref
# 6424             10        1       12          ref
# ...             ...      ...      ...          ...
# 527              40        1       12      non_rep
# 528              40        1       12      non_rep
# 529              40        1       12      non_rep
# 530              40        1       12      non_rep
# 531              40        1       12      non_rep
#
#                                     Metadata_moa         dropout
# 6420                                        None    All Channels
# 6421                                        None    All Channels
# 6422                                        None    All Channels
# 6423                                        None    All Channels
# 6424                                        None    All Channels
# ...                                          ...             ...
# 527      pyruvate dehydrogenase kinase inhibitor  No BrightField
# 528                  smoothened receptor agonist  No BrightField
# 529                     tricyclic antidepressant  No BrightField
# 530   tumor necrosis factor production inhibitor  No BrightField
# 531        ubiquitin specific protease inhibitor  No BrightField
#
# [1064 rows x 38 columns]

# %%
metric_type = "ref"
x = "dropout"
y = "sim_retrieval_average_precision_i_mean_i"

plot_df = all_df[
    (~all_df["Batch"].str.contains("siteSub"))
]

plot_df = plot_df[plot_df["metric_type"] == metric_type].groupby(["Metadata_pert_iname", x]).mean().reset_index()

fig, ax = plt.subplots(figsize=(5,5))

plot = utilssphering.plot_two_distributions(
    plot_df,
    x,
    y,
    xlabel="Channel",
    ylabel="Mean Average Precision\n(Finding Replicates)",
    include_pval=True,
    ax=ax,
    fig=fig
)

plot.savefig("(S7A)-mAP_replicates-brightfield-drop.png", dpi=300)
# Out:
# The pvalue is: 0.214
# The pvalue is: 0.21397447601056474

# %%
metric_type = "non_rep"
x = "dropout"
y = "sim_retrieval_average_precision_i_mean_i"

plot_df = all_df[
    (~all_df["Batch"].str.contains("siteSub"))
]

plot_df = plot_df[plot_df["metric_type"] == metric_type].groupby(["Metadata_moa", x]).mean().reset_index()

fig, ax = plt.subplots(figsize=(5,5))

plot = utilssphering.plot_two_distributions(
    plot_df,
    x,
    y,
    xlabel="Channel",
    ylabel="Mean Average Precision\n(Finding MoA Matches)",
    include_pval=True,
    ax=ax,
    fig=fig
)

plot.savefig("(S7B)-mAP_matches-brightfield-drop.png", dpi=300)
# Out:
# The pvalue is: 0.583
# The pvalue is: 0.5829098320472328

# %%
all_channels_df = pd.read_parquet("../../../data/evalzoo_metrics_combined.paraquet")

rna_drop_df = pd.read_parquet("rna-drop-evalzoo-combined.parquet")

# Keep only the profiles that are tested in brightfield
subset_all_df = all_channels_df[
    (all_channels_df["Metadata_Plate"].isin(rna_drop_df["Metadata_Plate"])) & 
    (~all_channels_df["Batch"].str.contains("siteSub"))
     ].copy()

subset_all_df.loc[:, "dropout"] = "All Channels"
rna_drop_df.loc[:, "dropout"] = "No RNA"

print(subset_all_df.shape, rna_drop_df.shape)

all_df = pd.concat([subset_all_df, rna_drop_df], axis=0)
all_df
# Out:
# (6403, 38) (6403, 38)
#                                   Batch                    Metadata_Plate  \
# 0                     Scope1_MolDev_10X        Plate2_PCO_6ch_4site_10XPA
# 1                     Scope1_MolDev_10X  Plate3_PCO_6ch_4site_10XPA_Crest
# 2                     Scope1_MolDev_10X        Plate2_PCO_6ch_4site_10XPA
# 3                     Scope1_MolDev_10X  Plate3_PCO_6ch_4site_10XPA_Crest
# 4                     Scope1_MolDev_10X        Plate2_PCO_6ch_4site_10XPA
# ...                                 ...                               ...
# 6398  Scope1_Yokogawa_US_40X_BRO0117059                    BRO0117059_40x
# 6399  Scope1_Yokogawa_US_40X_BRO0117059                    BRO0117059_40x
# 6400  Scope1_Yokogawa_US_40X_BRO0117059                    BRO0117059_40x
# 6401  Scope1_Yokogawa_US_40X_BRO0117059                    BRO0117059_40x
# 6402  Scope1_Yokogawa_US_40X_BRO0117059                    BRO0117059_40x
#
#      Metadata_pert_iname Metadata_reference_or_other  \
# 0                  A-366                        pert
# 1                  A-366                        pert
# 2                ABT-737                        pert
# 3                ABT-737                        pert
# 4                AMG-925                        pert
# ...                  ...                         ...
# 6398                None                        pert
# 6399                None                        pert
# 6400                None                        pert
# 6401                None                        pert
# 6402                None                        pert
#
#       sim_scaled_mean_i_mean_i  sim_scaled_mean_i_median_i  \
# 0                     0.017355                    0.034813
# 1                     0.017355                    0.034813
# 2                     1.550364                    1.901986
# 3                     1.550364                    1.901986
# 4                     2.544456                    2.651249
# ...                        ...                         ...
# 6398                  0.437982                    0.437982
# 6399                  0.538984                    0.538984
# 6400                  0.514045                    0.514045
# 6401                  0.563942                    0.563942
# 6402                  0.551460                    0.551460
#
#       sim_scaled_median_i_mean_i  sim_scaled_median_i_median_i  \
# 0                      -0.152331                     -0.183784
# 1                      -0.152331                     -0.183784
# 2                       1.559669                      1.654185
# 3                       1.559669                      1.654185
# 4                       2.358491                      2.587136
# ...                          ...                           ...
# 6398                    0.437982                      0.437982
# 6399                    0.538984                      0.538984
# 6400                    0.514045                      0.514045
# 6401                    0.563942                      0.563942
# 6402                    0.551460                      0.551460
#
#       sim_ranked_relrank_mean_i_mean_i  sim_ranked_relrank_mean_i_median_i  \
# 0                             0.505952                            0.531250
# 1                             0.505952                            0.531250
# 2                             0.158854                            0.126488
# 3                             0.158854                            0.126488
# 4                             0.101935                            0.093750
# ...                                ...                                 ...
# 6398                          0.443182                            0.443182
# 6399                          0.250000                            0.250000
# 6400                          0.363636                            0.363636
# 6401                          0.187500                            0.187500
# 6402                          0.210227                            0.210227
#
#       ...  sim_retrieval_average_precision_i_nlog10pvalue_mean_i  \
# 0     ...                                           0.333687
# 1     ...                                           0.333687
# 2     ...                                           2.727806
# 3     ...                                           2.727806
# 4     ...                                           3.290924
# ...   ...                                                ...
# 6398  ...                                           0.423867
# 6399  ...                                           0.735217
# 6400  ...                                           0.533170
# 6401  ...                                           0.785308
# 6402  ...                                           0.758333
#
#       sim_retrieval_average_precision_i_nlog10pvalue_median_i  \
# 0                                              0.277463
# 1                                              0.277463
# 2                                              3.008908
# 3                                              3.008908
# 4                                              4.000043
# ...                                                 ...
# 6398                                           0.423867
# 6399                                           0.735217
# 6400                                           0.533170
# 6401                                           0.785308
# 6402                                           0.758333
#
#       sim_retrieval_average_precision_i_nlog10qvalue_mean_i       Vendor  \
# 0                                              0.308864           MolDev
# 1                                              0.308864           MolDev
# 2                                              2.293433           MolDev
# 3                                              2.293433           MolDev
# 4                                              2.591954           MolDev
# ...                                                 ...              ...
# 6398                                           0.259454      Yokogawa_US
# 6399                                           0.335998      Yokogawa_US
# 6400                                           0.305909      Yokogawa_US
# 6401                                           0.335998      Yokogawa_US
# 6402                                           0.335998      Yokogawa_US
#
#       Magnification  Binning  z_plane  metric_type  \
# 0                10        1        1          ref
# 1                10        1        1          ref
# 2                10        1        1          ref
# 3                10        1        1          ref
# 4                10        1        1          ref
# ...             ...      ...      ...          ...
# 6398             40        1       12      non_rep
# 6399             40        1       12      non_rep
# 6400             40        1       12      non_rep
# 6401             40        1       12      non_rep
# 6402             40        1       12      non_rep
#
#                                     Metadata_moa       dropout
# 0                                           None  All Channels
# 1                                           None  All Channels
# 2                                           None  All Channels
# 3                                           None  All Channels
# 4                                           None  All Channels
# ...                                          ...           ...
# 6398     pyruvate dehydrogenase kinase inhibitor        No RNA
# 6399                 smoothened receptor agonist        No RNA
# 6400                    tricyclic antidepressant        No RNA
# 6401  tumor necrosis factor production inhibitor        No RNA
# 6402       ubiquitin specific protease inhibitor        No RNA
#
# [12806 rows x 38 columns]

# %%
metric_type = "ref"
x = "dropout"
y = "sim_retrieval_average_precision_i_mean_i"

plot_df = all_df[
    (~all_df["Batch"].str.contains("siteSub")) #&
    # (all_df["Vendor"].str.contains("Yokogawa_US"))
]

plot_df = plot_df[plot_df["metric_type"] == metric_type].groupby(["Metadata_pert_iname", x]).mean().reset_index()

fig, ax = plt.subplots(figsize=(5,5))

plot = utilssphering.plot_two_distributions(
    plot_df,
    x,
    y,
    xlabel="Channel",
    ylabel="Mean Average Precision\n(Finding Replicates)",
    include_pval=True,
    ax=ax,
    fig=fig
)

plot.savefig("(S7C)-mAP_replicates-RNA-drop.png", dpi=300)
# Out:
# The pvalue is: 0.019
# The pvalue is: 0.01904534181158718

# %%
metric_type = "non_rep"
x = "dropout"
y = "sim_retrieval_average_precision_i_mean_i"

plot_df = all_df[
    (~all_df["Batch"].str.contains("siteSub"))
]

plot_df = plot_df[plot_df["metric_type"] == metric_type].groupby(["Metadata_moa", x]).mean().reset_index()

fig, ax = plt.subplots(figsize=(5,5))

plot = utilssphering.plot_two_distributions(
    plot_df,
    x,
    y,
    xlabel="Channel",
    ylabel="Mean Average Precision\n(Finding MoA Matches)",
    include_pval=True,
    ax=ax,
    fig=fig
)

plot.savefig("(S7D)-mAP_matches-RNA-drop.png", dpi=300)
# Out:
# The pvalue is: 0.973
# The pvalue is: 0.9728963248888831
