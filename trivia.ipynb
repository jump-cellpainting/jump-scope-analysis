# %% [markdown]
# # Notebook for finding interesting data on the JUMP-scope project
# - Number of images
# - number of sites
# - number of cells
# -

# %%
import pandas as pd
import os

# %%
match_rep_df = pd.read_csv("/Users/ctromans/image-analysis/jump_scope/jump-scope-analysis/checkpoints/match_rep_df.csv")

# %%
# Find the number of images loaded, as dictated by load_data_with_illum.csv

def find_trivia(metadata_df, load_data_path):
    plates = []
    df = metadata_df.copy()

    for root, dirs, files in os.walk(load_data_path):
        for file in files:
            if "load_data.csv" in file:
                path = os.path.join(root, file)
                plate = os.path.split(path)[0].split("/")[-1]
                load_data_df = pd.read_csv(path)
                # Find the number of image columns
                columns = load_data_df.columns.tolist()
                channels = sorted([i for i in columns if "FileName_Orig" in i])
                # Find number of rows
                rows = load_data_df.shape[0]
                # Total number of images = num_rows * num_channels
                num_images = rows * len(channels)
                df.loc[df["Assay_Plate_Barcode"] == plate, "image_num"] = num_images
                # Find total file
                image_size = df.loc[df["Assay_Plate_Barcode"] == plate, "Size_MB"]
                df.loc[df["Assay_Plate_Barcode"] == plate, "total_image_size_GB"] = (image_size * num_images) / 1000
    return df

no_sub = match_rep_df[
    (~match_rep_df["Batch"].str.contains("siteSub")) &
    (match_rep_df["sphering"] == True)
]

number_of_images = find_trivia(no_sub, "../jump-scope/load_data_csv/")

# %%
number_of_images["image_num"].sum()
# Out:
# 454638.0

# %%
number_of_images["total_image_size_GB"].sum()
# Out:
# 6786.468340043271

# %%
number_of_images["cell_count"].sum()
# Out:
# 41356132

# %%
# Total number of sites. This is less accurate since some profiles have 4/5/6 channels and perhaps not all
# images are analysed
number_of_images["sites"].sum() * 384 * 5
# Out:
# 441600

# %%
# How to calculate unique settings? Take only setting columns and remove duplicates?
# Thus this will find the number of unique setting combinations

setting_cols = [
    "aperture",
    "Magnification",
    "Modality",
    "Binning",
    "Number_of_channels",
    "z_plane",
    "spinning-disc",
    "dry-immersion",
    "vs-brightfield",
    "simultaneous-excitation",
    "sites",
    "channel_names",
    "Vendor"   
]

setts = number_of_images[setting_cols].drop_duplicates()

print(f"{setts.shape[0]} unique settings used")
# Out:
# 25 unique settings used

# %%
number_of_images.columns
# Out:
# Index(['Vendor', 'Batch', 'Plate_Map_Name', 'Assay_Plate_Barcode', 'Modality',
#        'Images_per_well', 'Sites-SubSampled', 'Binning', 'Magnification',
#        'Number_of_channels', 'z_plane', 'BF_Zplanes', 'spinning-disc',
#        'aperture', 'dry-immersion', 'vs-brightfield',
#        'simultaneous-excitation', 'sites', 'Size_MB', 'Size_MB_std',
#        'sphering', 'value_95_replicating', 'Percent_Replicating',
#        'channel_names', 'brightfield_z_plane_used', 'feature_channels_found',
#        'Percent_Matching', 'value_95_matching', 'cell_count', 'image_num',
#        'total_image_size_GB'],
#       dtype='object')

# %%
setts
# Out:
#      aperture  Magnification   Modality  Binning  Number_of_channels  z_plane  \
# 0        0.45             10   Confocal        1                   6        1
# 2        0.45             10   Confocal        1                   6        1
# 4        0.45             10   Confocal        1                   6        3
# 6        0.75             20   Confocal        1                   6        3
# 8        0.75             20   Confocal        1                   6        1
# 10       0.75             20   Confocal        1                   6        1
# 12       0.45             10  Widefield        1                   4        1
# 20       0.75             20  Widefield        1                   4        1
# 26       1.00             20   Confocal        1                   5        1
# 34       1.00             20   Confocal        1                   5        3
# 42       1.00             20  Widefield        1                   5        1
# 50       1.00             20  Widefield        1                   5        3
# 58       1.00             20   Confocal        2                   5        1
# 66       1.00             20   Confocal        2                   5        3
# 68       1.00             20   Confocal        2                   5        3
# 74       1.00             20  Widefield        2                   5        1
# 82       1.00             20  Widefield        2                   5        3
# 84       1.00             20  Widefield        2                   5        3
# 90       0.75             20   Confocal        1                   5       10
# 92       0.95             40   Confocal        1                   5       12
# 94       0.40             10   Confocal        1                   6       12
# 96       1.00             20   Confocal        1                   5        1
# 100      1.00             20   Confocal        1                   5       12
# 102      1.00             20   Confocal        1                   6       12
# 106      1.00             40   Confocal        1                   6       12
#
#     spinning-disc dry-immersion vs-brightfield  simultaneous-excitation  \
# 0              no           dry            NaN                      NaN
# 2             yes           dry            NaN                      NaN
# 4             yes           dry            NaN                      NaN
# 6             yes           dry            NaN                      NaN
# 8              no           dry            NaN                      NaN
# 10            yes           dry            NaN                      NaN
# 12            NaN           dry            NaN                      NaN
# 20            NaN           dry            NaN                      NaN
# 26            NaN         water            NaN                      NaN
# 34            NaN         water            NaN                      NaN
# 42            NaN         water            NaN                      NaN
# 50            NaN         water            NaN                      NaN
# 58            NaN         water            NaN                      NaN
# 66            NaN         water            NaN                      NaN
# 68            NaN         water            NaN                      NaN
# 74            NaN         water            NaN                      NaN
# 82            NaN         water            NaN                      NaN
# 84            NaN         water            NaN                      NaN
# 90            NaN           dry            NaN                      NaN
# 92            NaN           dry             no                      NaN
# 94            NaN           dry            yes                      2.0
# 96            NaN         water             no                      2.0
# 100           NaN         water             no                      2.0
# 102           NaN         water            yes                      4.0
# 106           NaN         water            yes                      4.0
#
#      sites                         channel_names
# 0        4      Actin, DNA, ER, Golgi, Mito, RNA
# 2        4      Actin, DNA, ER, Golgi, Mito, RNA
# 4        4      Actin, DNA, ER, Golgi, Mito, RNA
# 6        4      Actin, DNA, ER, Golgi, Mito, RNA
# 8        9      Actin, DNA, ER, Golgi, Mito, RNA
# 10       9      Actin, DNA, ER, Golgi, Mito, RNA
# 12       1                    AGP, DNA, ER, Mito
# 20       9                    AGP, DNA, ER, Mito
# 26       3      DNA, ER, Mito, RNA, WGPhalloidin
# 34       3      DNA, ER, Mito, RNA, WGPhalloidin
# 42       3      DNA, ER, Mito, RNA, WGPhalloidin
# 50       3      DNA, ER, Mito, RNA, WGPhalloidin
# 58       3      DNA, ER, Mito, RNA, WGPhalloidin
# 66       3      DNA, ER, Mito, RNA, WGPhalloidin
# 68       3               AGP, DNA, ER, Mito, RNA
# 74       3      DNA, ER, Mito, RNA, WGPhalloidin
# 82       3               AGP, DNA, ER, Mito, RNA
# 84       3      DNA, ER, Mito, RNA, WGPhalloidin
# 90       9               AGP, DNA, ER, Mito, RNA
# 92       2               AGP, DNA, ER, Mito, RNA
# 94       4  AGP, BrightField, DNA, ER, Mito, RNA
# 96       9               AGP, DNA, ER, Mito, RNA
# 100      9               AGP, DNA, ER, Mito, RNA
# 102      9  AGP, BrightField, DNA, ER, Mito, RNA
# 106      9  AGP, BrightField, DNA, ER, Mito, RNA

# %%
number_of_images
# Out:
#           Vendor                                   Batch  \
# 0         MolDev                       Scope1_MolDev_10X
# 1         MolDev                       Scope1_MolDev_10X
# 2         MolDev                       Scope1_MolDev_10X
# 3         MolDev                       Scope1_MolDev_10X
# 4         MolDev                Scope1_MolDev_10X_4siteZ
# ..           ...                                     ...
# 103  Yokogawa_US   Scope1_Yokogawa_US_20X_6Ch_BRO0117059
# 104  Yokogawa_US  Scope1_Yokogawa_US_20X_6Ch_BRO01177034
# 105  Yokogawa_US  Scope1_Yokogawa_US_20X_6Ch_BRO01177034
# 106  Yokogawa_US       Scope1_Yokogawa_US_40X_BRO0117059
# 107  Yokogawa_US       Scope1_Yokogawa_US_40X_BRO0117059
#
#                  Plate_Map_Name                Assay_Plate_Barcode  Modality  \
# 0    JUMP-MOA_compound_platemap         Plate2_PCO_6ch_4site_10XPA  Confocal
# 1    JUMP-MOA_compound_platemap         Plate2_PCO_6ch_4site_10XPA  Confocal
# 2    JUMP-MOA_compound_platemap   Plate3_PCO_6ch_4site_10XPA_Crest  Confocal
# 3    JUMP-MOA_compound_platemap   Plate3_PCO_6ch_4site_10XPA_Crest  Confocal
# 4    JUMP-MOA_compound_platemap  Plate3_PCO_6ch_4site_10XPA_Crestz  Confocal
# ..                          ...                                ...       ...
# 103  JUMP-MOA_compound_platemap                     BRO0117059_20X  Confocal
# 104  JUMP-MOA_compound_platemap                    BRO01177034_20x  Confocal
# 105  JUMP-MOA_compound_platemap                    BRO01177034_20x  Confocal
# 106  JUMP-MOA_compound_platemap                     BRO0117059_40x  Confocal
# 107  JUMP-MOA_compound_platemap                     BRO0117059_40x  Confocal
#
#      Images_per_well  Sites-SubSampled  Binning  Magnification  \
# 0                  4               NaN        1             10
# 1                  4               NaN        1             10
# 2                  4               NaN        1             10
# 3                  4               NaN        1             10
# 4                  4               NaN        1             10
# ..               ...               ...      ...            ...
# 103                9               NaN        1             20
# 104                9               NaN        1             20
# 105                9               NaN        1             20
# 106                9               NaN        1             40
# 107                9               NaN        1             40
#
#      Number_of_channels  ...  value_95_replicating Percent_Replicating  \
# 0                     6  ...              0.191908           60.000000
# 1                     6  ...              0.269727           53.333333
# 2                     6  ...              0.269617           62.222222
# 3                     6  ...              0.329074           45.555556
# 4                     6  ...              0.205121           66.666667
# ..                  ...  ...                   ...                 ...
# 103                   6  ...              0.407403           56.666667
# 104                   6  ...              0.206867           58.888889
# 105                   6  ...              0.261967           54.444444
# 106                   6  ...              0.181967           54.444444
# 107                   6  ...              0.370124           45.555556
#
#                             channel_names  brightfield_z_plane_used  \
# 0        Actin, DNA, ER, Golgi, Mito, RNA                       NaN
# 1        Actin, DNA, ER, Golgi, Mito, RNA                       NaN
# 2        Actin, DNA, ER, Golgi, Mito, RNA                       NaN
# 3        Actin, DNA, ER, Golgi, Mito, RNA                       NaN
# 4        Actin, DNA, ER, Golgi, Mito, RNA                       NaN
# ..                                    ...                       ...
# 103  AGP, BrightField, DNA, ER, Mito, RNA                       Z08
# 104  AGP, BrightField, DNA, ER, Mito, RNA                       Z17
# 105  AGP, BrightField, DNA, ER, Mito, RNA                       Z17
# 106  AGP, BrightField, DNA, ER, Mito, RNA                       Z08
# 107  AGP, BrightField, DNA, ER, Mito, RNA                       Z08
#
#                    feature_channels_found Percent_Matching  value_95_matching  \
# 0        Actin, DNA, ER, Golgi, Mito, RNA        23.255814           0.288099
# 1        Actin, DNA, ER, Golgi, Mito, RNA        18.604651           0.320855
# 2        Actin, DNA, ER, Golgi, Mito, RNA        18.604651           0.398249
# 3        Actin, DNA, ER, Golgi, Mito, RNA        18.604651           0.389170
# 4        Actin, DNA, ER, Golgi, Mito, RNA        23.255814           0.363114
# ..                                    ...              ...                ...
# 103  AGP, BrightField, DNA, ER, Mito, RNA        20.930233           0.480152
# 104  AGP, BrightField, DNA, ER, Mito, RNA        18.604651           0.318081
# 105  AGP, BrightField, DNA, ER, Mito, RNA        20.930233           0.360108
# 106  AGP, BrightField, DNA, ER, Mito, RNA        18.604651           0.266650
# 107  AGP, BrightField, DNA, ER, Mito, RNA        13.953488           0.455924
#
#      cell_count  image_num  total_image_size_GB
# 0       2014937     9210.0           483.307032
# 1       2014937     9210.0           483.307032
# 2       2413350     9216.0           483.623555
# 3       2413350     9216.0           483.623555
# 4       2381443     9198.0           482.680056
# ..          ...        ...                  ...
# 103     1136319    20724.0           164.847787
# 104     1045379    20790.0           166.394513
# 105     1045379    20790.0           166.394513
# 106      279900    20706.0           165.060538
# 107      279900    20706.0           165.060538
#
# [108 rows x 31 columns]

# %%
df = pd.read_csv("/Users/ctromans/image-analysis/jump_scope/jump-scope/load_data_csv/2020_10_27_Scope1_YokogawaJapan/20201020T134356/load_data_with_illum.csv")

# %%
df.columns
# Out:
# Index(['FileName_OrigDNA', 'PathName_OrigDNA', 'FileName_OrigER',
#        'PathName_OrigER', 'FileName_OrigRNA', 'PathName_OrigRNA',
#        'FileName_OrigAGP', 'PathName_OrigAGP', 'FileName_OrigMito',
#        'PathName_OrigMito', 'Metadata_Plate', 'Metadata_Well', 'Metadata_Site',
#        'FileName_IllumDNA', 'PathName_IllumDNA', 'FileName_IllumER',
#        'PathName_IllumER', 'FileName_IllumRNA', 'PathName_IllumRNA',
#        'FileName_IllumAGP', 'PathName_IllumAGP', 'FileName_IllumMito',
#        'PathName_IllumMito'],
#       dtype='object')

# %%
[i for i in df.columns if "FileName_Orig" in i]
# Out:
# ['FileName_OrigDNA',
#  'FileName_OrigER',
#  'FileName_OrigRNA',
#  'FileName_OrigAGP',
#  'FileName_OrigMito']
